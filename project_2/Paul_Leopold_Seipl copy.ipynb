# %% [markdown]
# # Mini Project 2
#
# By the deadline, please submit the provided Jupyter notebook with all/some required tasks completed and clearly solved. Make sure your code is neat, well-commented, and that all outputs are visible (run all cells before saving). Notebooks with missing tasks or unexecuted cells may receive fewer points. After you submit, you won’t be able to make changes, so double-check your work and be sure to start from the provided template
#
# ## Submission rules
# As already discussed in class, we will stick to the following rules.
# - Use the templates and name your files `NAME_SURNAME.ipynb` (If you have more than one name, just concatenate them). We will compare what you present with that file.
# - Code either not written in Python or not using PyTorch receives a grade of 0. Of course, you can use auxiliary packages when needed (`matplotlib`, `numpy`, ...), but for the learning part, you must use PyTorch.
# -  If plagiarism is suspected, TAs and I will thoroughly investigate the situation, and we will summon the student for a face-to-face clarification regarding certain answers they provided. In case of plagiarism, a score reduction will be applied to all the people involved, depending on their level of involvement.
# -  If extensive usage of AI tools is detected, we will summon the student for a face-to-face clarification regarding certain answers they provided. If the answers are not adequately supported with in-person answers, we will proceed to apply a penalty to the evaluation, ranging from 10% to 100%.

# %%
import matplotlib.pyplot as plt
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
from torch.utils.data import DataLoader

# %% [markdown]
# ## Image classification uning a CNN
#
# The CIFAR-10 dataset is a widely used collection of images in the field of computer vision. It consists of 60000 (50000 for the training and 10000 for the test) 32x32 color images across 10 different classes, with each class containing 6,000 images. These classes include common objects such as airplanes, automobiles, cats, and dogs. CIFAR-10 serves as a benchmark for image classification tasks and has been instrumental in developing and evaluating machine learning algorithms for image recognition.
# The task of this assignment is to classify the images

# %% [markdown]
# ### Task 0 (0 pts)
# Understand what's going on in the two cells below. Do the following experiments:
# 1. Run the first and the second cell in a row.
# 2. Run the first cell and two times in a row the second one.
#
# What do you observe? We don't need any answer, but please just keep this phenomenon in mind.

# %%
torch.manual_seed(0)

# %%
torch.randint(1, 10 , (1,1))
# Out:
# tensor([[9]])

# %% [markdown]
# Now, we'll set a seed that will remain the same for all the code below

# %% [markdown]
# ### Task 1 (2.5 pts)
# Load the [data (You can do it directly in PyTorch)](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html) and take some time to inspect the dataset. Report here at least one image per class and a histogram of the distribution of the images of the training and test set.

# %%
# download training data
dataset_train = torchvision.datasets.CIFAR10('./cifar10', train=True, download=True)
dataset_test = torchvision.datasets.CIFAR10('./cifar10', train=False, download=True)

# %%
# print basic information
print(dataset_train)
print(dataset_train[0])
print("Classes: ", dataset_train.classes)
print(f"There are {len(dataset_train)} for training and {len(dataset_test)} for testing.")

# get one image of each class
samples = {}
for img, label in dataset_train:
    if label not in samples:
        samples[label] = img
    if len(samples) == len(dataset_train.classes):
        break

# show images with corresponding label
fig, axs = plt.subplots(2, len(dataset_train.classes)//2)
for ax, label_ix, img in zip(axs.flatten(), samples.keys(), samples.values()):
    ax.imshow(img)
    ax.set_title(dataset_train.classes[label_ix])
    ax.set_axis_off()

fig.set_size_inches(10, 4)
plt.show()
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./cifar10
#     Split: Train
# (<PIL.Image.Image image mode=RGB size=32x32 at 0x7D4C5ED71E10>, 6)
# Classes:  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# There are 50000 for training and 10000 for testing.

# %%
# display histogram of training and test dataset
get_labels = lambda dataset: [data[1] for data in dataset]
bins = len(dataset_train.classes)
plt.hist([get_labels(dataset_train), get_labels(dataset_test)], label=['train', 'test'])
plt.legend(loc='best')
plt.xticks(range(len(dataset_train.classes)))
plt.show()

# %% [markdown]
# ### Task 2 (2.5 pts)
# Are the entries in the correct type for the DL framework in PyTorch? How can you arrive at a suitable format for your training pipeline? Be sure to have understood
# - The type of each element of the dataset
# - How we can convert it to a suitable type.
# - The dimension of the image as a `torch.Tensor` object
# - The meaning of each dimension of the images
#
# ## Answers
#
# > Are the entries in the correct type for the DL framework in PyTorch?
#
# No, they are not. They are PIL images from the pillow library.
# >  How can you arrive at a suitable format for your training pipeline?
#
# By transforming them to tensors with `torchvision.transforms.ToTensor()`. We can pass this class as a parameter when loading the data
# > The type of each element of the dataset
#
# When loaded without a transformer the elements of the dataset are tuples consisting of the PIL image and a label (number). When loaded with transformation to a tensor the PIL image is transformed to a tensor with type
# > How we can convert it to a suitable type.
#
# Using a transformer class
#
# > The dimension of the image as a `torch.Tensor` object
# > The meaning of each dimension of the images
#
# [3, 32, 32] <=> [Channels(RGB), Height, Width]

# %%
# add transformer to datasets to get images as tensors
dataset_train.transform = transforms.ToTensor()
dataset_test.transform = transforms.ToTensor()

# %% [markdown]
# ### Task 3 (10 pts)
# When you arrive at this question you should have each entry as a `torch.Tensor` of shape (3,32, 32) and clear the meaning of each dimension. A good practice in DL is to work with features having mean 0 and standard deviation equal to 1. Convert the dataset of the images in this format. To do so, you can do it from scratch (not recommended) or use the function [`torchvision.transforms.Normalize`](https://pytorch.org/vision/0.8/transforms.html\#torchvision.transforms.Normalize). If you go for this second option, don't forget that we have already transformed our dataset in the previous point, hence, it could be of help using the function [`transforms.Compose`](https://pytorch.org/vision/0.8/transforms.html\#torchvision.transforms.Compose). You can see an example in the tutorial linked above.
#
# **Note** that the usage of the function is tricky: try to really understand what's going on

# %%
# calculate std and mean of each channel
def get_std_mean(dataset, batch_size=None):
    batch_size = batch_size if batch_size else len(dataset_test)
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
    all_images = next(iter(loader))[0]
    return torch.std_mean(all_images, dim=[0, 2, 3])

# %%
stds_train, means_train = get_std_mean(dataset_train)
stds_test, means_test = get_std_mean(dataset_test)
print("Calculated mean train:", means_train)
print("Calculated std train:", stds_train)
# Out:
# Calculated mean train: tensor([0.4935, 0.4834, 0.4472])
# Calculated std train: tensor([0.2476, 0.2446, 0.2626])

# %%
# update transform to include normalization with computed means/stds
dataset_train.transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(means_train, stds_train)]
)
dataset_test.transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(means_test, stds_test)]
)

print("shape: ", dataset_train[0][0].shape, "dtype: ", dataset_train[0][0].dtype)
# Out:
# shape:  torch.Size([3, 32, 32]) dtype:  torch.float32

# %%
# Recalculate mean and std after normalization to verify
stds, means = get_std_mean(dataset_train, batch_size=5000)
print("Mean after normalization (should be ~0):", means)
print("Std after normalization (should be ~1):", stds)
# Out:
# Mean after normalization (should be ~0): tensor([-0.0089, -0.0080, -0.0103])
# Std after normalization (should be ~1): tensor([0.9999, 0.9996, 1.0005])

# %% [markdown]
# ### Task 4 (1 pts)
# As you might have observed, we only have a train and test set. We need a validation set for hyperparameter tuning. Create a validation set by splitting the test set.

# %%
dataset_validation, dataset_test = torch.utils.data.random_split(dataset_test, [0.5, 0.5])

# %% [markdown]
# ### Task 5 (20 pts)
# Starting from the code provided during Lecture 6, define a ConvNet. You can **only** use:
#
# - Convolutional layers
# - Max/Avg Pooling layers
# - Activation Functions
# - Fully connected layers
#
# Note that the choice `Conv - Pool - Conv` is not mandatory. Have you tried `Conv - Conv - Activ - Pool - Conv - Conv - Activ - Pool - FC`?
# For each convolutional layer you can choose padding and stride. Be prepared on comment on the choices of the dimensions of the layers.

# %%
from math import floor

def out_dimensions(conv_layer, h_in, w_in):
    '''
    This function computes the output dimension of each convolutional layers in the most general way. 
    See here https://docs.pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
    '''
    h_out = floor((h_in + 2 * conv_layer.padding[0] - conv_layer.dilation[0] * (conv_layer.kernel_size[0] - 1) - 1) /
                  conv_layer.stride[0] + 1)
    w_out = floor((w_in + 2 * conv_layer.padding[1] - conv_layer.dilation[1] * (conv_layer.kernel_size[1] - 1) - 1) /
                  conv_layer.stride[1] + 1)
    return h_out, w_out

class Model_OG(nn.Module):
    def __init__(self, channels=3, height=32, width=32):
        super().__init__()
        
        conv1 = nn.Conv2d(channels, 32, kernel_size=5, padding=2)
        h_out, w_out = out_dimensions(conv1, height, width)
        pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        h_out, w_out = out_dimensions(conv2, h_out, w_out)
        pool2 = nn.AvgPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        
        conv3 = nn.Conv2d(32, 20, kernel_size=3, padding=1)
        h_out, w_out = out_dimensions(conv3, h_out, w_out)
        pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        
        self.conv_seq = nn.Sequential(conv1, pool1, nn.ReLU(), conv2, pool2, nn.ReLU(), conv3, pool3, nn.ReLU())
        
        self.fc1 = nn.Linear(20 * h_out * w_out, out_features=120)
        self.fc2 = nn.Linear(120, out_features=10)
        
        self.dimensions_final = (20, h_out, w_out)
        
    def forward(self, x):
        x = self.conv_seq(x)
        
        n_channels, h, w = self.dimensions_final
        x = x.view(-1, n_channels * h * w)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        
        return x

print(Model_OG(3, 32))
print(Model_OG(3, 32).dimensions_final)
# Out:
# Model_OG(
#   (conv_seq): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (5): ReLU()
#     (6): Conv2d(32, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU()
#   )
#   (fc1): Linear(in_features=320, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=10, bias=True)
# )
# (20, 4, 4)

# %% [markdown]
# ### Task 6 (35 pts)
# Implement the training pipeline. Make sure to code the following:
#
# - Print and record the current training loss and accuracy every *n* steps (choose *n*)
# - Print and record the current validation loss and accuracy every *n* steps (choose *n*)
#
# The validation loss will help you in hyperparameter tuning. Train your model.
# With my choice of hyperparameters, the best test accuracy is above **65%**, hence, a necessary condition to get full marks is to achieve an accuracy on the test set greater or equal to **65%**.
#
# You may want to follow some of these hints (**They are, of course, dependent on the architecture, optimizer, ...**):
#
# - 5 epochs should be enough
# - Batch size = 32 could be a good starting point
# - A learning rate around 0.03 should be a good tradeoff between speed and stability
# - SGD should be a good optimizer
#
# Be prepared to answer the following questions:
# - Why that learning rate? Why not higher/smaller?
# - Number of epochs: Why that number?
# - Some comments on your architecture: why that deep? why not deeper? why not smaller?

# %%
import copy

class EarlyStopping():
    def __init__(self, patience=5, min_delta=0, restore_best_weights=True):
        self.patience = patience
        self.min_delta = min_delta # minimum improvement to reset patience
        self.restore_best_weights = restore_best_weights
        self.best_model = None
        self.best_loss = None
        self.counter = 0
        self.status = ""
        
    def __call__(self, model, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.best_model = copy.deepcopy(model)
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
            self.best_model.load_state_dict(model.state_dict())
        elif self.best_loss - val_loss < self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.status = f"Stopped on {self.counter}"
                if self.restore_best_weights:
                    model.load_state_dict(self.best_model.state_dict())
                return True
        self.status = f"{self.counter}/{self.patience}"
        return False

# %%
model = Model_OG(3, 32)
early_stop = EarlyStopping(patience=10, min_delta=0.01)
learning_rate = 0.03
batch_size = 32
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss()
print(model.dimensions_final)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'mps' 
    if torch.backends.mps.is_available() else 'cpu')
model = model.to(DEVICE)
print("Working on", DEVICE)
# Out:
# (20, 4, 4)
# Working on cuda

# %%
train_loader = DataLoader(dataset_train, batch_size=batch_size, pin_memory=True, num_workers=2)
validation_loader = DataLoader(dataset_validation, batch_size=len(dataset_validation), pin_memory=True, num_workers=2)
test_loader = DataLoader(dataset_test, batch_size=len(dataset_test), pin_memory=True, num_workers=2)

# %%
def evaluate_model(model, data_loader, loss_fn):
    model.eval()
    total_loss = 0
    n_correct = 0
    n_samples = 0
    
    for data, target in data_loader: # Just one batch
            data, target = data.to(DEVICE), target.to(DEVICE)
            # Make a prediction
            output = model(data)
            # Compute the loss function
            total_loss += loss_fn(output, target).item()
            # Compute the accuracy
            _, predicted = torch.max(output.data, 1)
            n_samples += target.size(0)
            n_correct += (predicted == target).sum().item()
        
    avg_loss = total_loss / len(data_loader)
    accuracy = 100.0 * n_correct / n_samples
    return avg_loss, accuracy

# %%
def fit(model, epochs=5, logging_interval=250):
    epochs
    train_loss_list = []
    train_acc_list = []
    val_loss_list = []
    val_acc_list = []
    for epoch in range(epochs):
        n_correct = 0
        n_samples = 0
        loss_train = 0
        for step, (data, target) in enumerate(train_loader):
            # Set the model in training mode
            model.train()
            data, target = data.to(DEVICE), target.to(DEVICE)
            # Set the gradient to 0
            optimizer.zero_grad()
            # Make a prediction
            output = model(data)
            # Compute the loss function
            loss = loss_fn(output, target)
            loss_train += loss.item()
            # Backpropagation
            loss.backward()
            # Update parameters
            optimizer.step()
            # Compute the training accuracy
            _, predicted = torch.max(output.data, 1)
            n_samples += target.size(0)
            n_correct += (predicted == target).sum().item()
            # Log every logging_interval steps train and validation loss and accuracy
            if (step + 1) % logging_interval == 0:
                # Calculate avg train loss and acc over last steps
                avg_loss_train = loss_train / logging_interval
                avg_train_acc = 100.0 * n_correct / n_samples
                # Validate
                val_loss, val_acc = evaluate_model(model, validation_loader, loss_fn)
                
                print(f"Epoch {epoch+1}, Step {step+1}: " 
                    f"Training Loss: {avg_loss_train:.4f}, Training Accuracy: {avg_train_acc:.2f}% | "
                    f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.2f}%")
                
                train_loss_list.append(avg_loss_train)
                train_acc_list.append(avg_train_acc)
                val_loss_list.append(val_loss)
                val_acc_list.append(val_acc)
                # Reset
                loss_train, n_samples, n_correct = 0, 0, 0
                
                    # Early stopping check
                if early_stop(model, val_loss):
                    print(f"Stopped trained at epoch {epoch}")
                    break
                
        # Log remaining batches
        remainder = (step + 1) % logging_interval
        if remainder != 0:
            avg_loss_train = loss_train / remainder
            avg_train_acc = 100.0 * n_correct / n_samples
            val_loss, val_acc = evaluate_model(model, validation_loader, loss_fn)
            
            print(f"Epoch {epoch+1}, Step {step+1}: "
                f"Train Loss: {avg_loss_train:.4f}, Train Acc: {avg_train_acc:.2f}% | "
                f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
            
            train_loss_list.append(avg_loss_train)
            train_acc_list.append(avg_train_acc)
            val_loss_list.append(val_loss)
            val_acc_list.append(val_acc)
        
        return model, train_loss_list, train_acc_list, val_loss_list, val_acc_list
# Out:
# Epoch 1, Step 250: Training Loss: 2.2657, Training Accuracy: 13.99% | Val Loss: 2.1026, Val Accuracy: 24.26%
# Epoch 1, Step 500: Training Loss: 1.9935, Training Accuracy: 27.43% | Val Loss: 1.9426, Val Accuracy: 27.72%
# Epoch 1, Step 750: Training Loss: 1.7669, Training Accuracy: 35.54% | Val Loss: 1.6532, Val Accuracy: 39.36%
# Epoch 1, Step 1000: Training Loss: 1.6440, Training Accuracy: 39.88% | Val Loss: 1.5808, Val Accuracy: 42.16%
# Epoch 1, Step 1250: Training Loss: 1.5885, Training Accuracy: 42.51% | Val Loss: 1.5300, Val Accuracy: 43.26%
# Epoch 1, Step 1500: Training Loss: 1.5268, Training Accuracy: 44.81% | Val Loss: 1.4668, Val Accuracy: 47.26%
# Epoch 1, Step 1563: Train Loss: 1.4941, Train Acc: 44.81% | Val Loss: 1.6187, Val Acc: 39.58%
# Epoch 2, Step 250: Training Loss: 1.4548, Training Accuracy: 47.38% | Val Loss: 1.3950, Val Accuracy: 49.54%
# Epoch 2, Step 500: Training Loss: 1.4270, Training Accuracy: 48.09% | Val Loss: 1.4503, Val Accuracy: 48.22%
# Epoch 2, Step 750: Training Loss: 1.3471, Training Accuracy: 51.95% | Val Loss: 1.3243, Val Accuracy: 52.64%
# Epoch 2, Step 1000: Training Loss: 1.2973, Training Accuracy: 53.55% | Val Loss: 1.2674, Val Accuracy: 54.94%
# Epoch 2, Step 1250: Training Loss: 1.2913, Training Accuracy: 54.11% | Val Loss: 1.2745, Val Accuracy: 54.36%
# Epoch 2, Step 1500: Training Loss: 1.2485, Training Accuracy: 54.91% | Val Loss: 1.2407, Val Accuracy: 56.04%
# Epoch 2, Step 1563: Train Loss: 1.2128, Train Acc: 54.91% | Val Loss: 1.3274, Val Acc: 52.72%
# Epoch 3, Step 250: Training Loss: 1.2127, Training Accuracy: 57.20% | Val Loss: 1.2023, Val Accuracy: 57.54%
# Epoch 3, Step 500: Training Loss: 1.1944, Training Accuracy: 57.31% | Val Loss: 1.2180, Val Accuracy: 57.02%
# Epoch 3, Step 750: Training Loss: 1.1404, Training Accuracy: 59.75% | Val Loss: 1.1368, Val Accuracy: 59.44%
# Epoch 3, Step 1000: Training Loss: 1.1003, Training Accuracy: 61.05% | Val Loss: 1.1020, Val Accuracy: 60.98%
# Epoch 3, Step 1250: Training Loss: 1.1136, Training Accuracy: 60.39% | Val Loss: 1.1552, Val Accuracy: 58.90%
# Epoch 3, Step 1500: Training Loss: 1.0854, Training Accuracy: 61.05% | Val Loss: 1.0975, Val Accuracy: 61.06%
# Epoch 3, Step 1563: Train Loss: 1.0481, Train Acc: 61.05% | Val Loss: 1.1816, Val Acc: 58.06%
# Epoch 4, Step 250: Training Loss: 1.0641, Training Accuracy: 62.31% | Val Loss: 1.0702, Val Accuracy: 62.48%
# Epoch 4, Step 500: Training Loss: 1.0597, Training Accuracy: 62.16% | Val Loss: 1.0647, Val Accuracy: 63.02%
# Epoch 4, Step 750: Training Loss: 1.0155, Training Accuracy: 64.42% | Val Loss: 1.0407, Val Accuracy: 63.06%
# Epoch 4, Step 1000: Training Loss: 0.9733, Training Accuracy: 65.35% | Val Loss: 1.0227, Val Accuracy: 63.48%
# Epoch 4, Step 1250: Training Loss: 0.9972, Training Accuracy: 64.35% | Val Loss: 1.0379, Val Accuracy: 63.92%
# Epoch 4, Step 1500: Training Loss: 0.9823, Training Accuracy: 64.94% | Val Loss: 1.0030, Val Accuracy: 64.54%
# Epoch 4, Step 1563: Train Loss: 0.9472, Train Acc: 64.94% | Val Loss: 1.0075, Val Acc: 63.90%
# Epoch 5, Step 250: Training Loss: 0.9585, Training Accuracy: 66.51% | Val Loss: 1.0236, Val Accuracy: 64.34%
# Epoch 5, Step 500: Training Loss: 0.9564, Training Accuracy: 66.30% | Val Loss: 1.0605, Val Accuracy: 63.68%
# Epoch 5, Step 750: Training Loss: 0.9206, Training Accuracy: 67.65% | Val Loss: 0.9878, Val Accuracy: 65.58%
# Epoch 5, Step 1000: Training Loss: 0.8830, Training Accuracy: 68.56% | Val Loss: 0.9690, Val Accuracy: 65.58%
# Epoch 5, Step 1250: Training Loss: 0.9142, Training Accuracy: 68.22% | Val Loss: 1.0292, Val Accuracy: 63.78%
# Epoch 5, Step 1500: Training Loss: 0.9017, Training Accuracy: 67.36% | Val Loss: 0.9933, Val Accuracy: 65.04%
# Epoch 5, Step 1563: Train Loss: 0.8711, Train Acc: 67.36% | Val Loss: 0.9697, Val Acc: 66.24%
#
# Test Accuracy: 65.62%

# %%
# Final test evaluation
logging_interval = 250
model, train_loss_list, train_acc_list, val_loss_list, val_acc_list = fit(model, logging_interval=logging_interval)
_, test_acc = evaluate_model(model, test_loader, loss_fn)
print(f"\nTest Accuracy: {test_acc:.2f}%")

# %% [markdown]
# ### Task 7 (4 pts)
# Plot the evolution of the training and validation losses on the same graph. On the x-axis, you should preferably use the number of steps. Do you observe signs of overfitting or underfitting? Note that an improperly trained model will also result in a point deduction for the previous exercise.

# %%
plt.figure(figsize=(10, 7))
steps = [x * logging_interval for x in range(len(train_loss_list))]
plt.plot(steps, train_loss_list, label='Training Loss')
plt.plot(steps, val_loss_list, label='Validation Loss')
plt.title("CIFER10")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task 8 (20 pts)
# You may have noticed that it is quite likely to get overfitting in many cases, preventing it from going beyond 65% accuracy.
#
# Change the architecture as you like and try to increase the accuracy as much as possible. The base architecture must remain a ConvNet.
# Try any idea that comes to your mind but **justify it**.
#
# Some hints:
#
# - Add Dropout (Any other hyperparameter to tune?)
# - Change activation functions ([GeLU](https://arxiv.org/pdf/1606.08415v3.pdf) is known to work well with images)
# - Make your CNN deeper
# - Add some regularization techniques
# - Change the optimizer
# - Data augmentation
# - Batch normalization
# - …
#
# #### Points distribution:
#
# - Any successful try (test accuracy increase): 6 points
# - Accuracy on test set ≥ 70% : 7 points
# - Accuracy on test set ≥ 72% : 8 points
# - Accuracy on test set ≥ 73% : 9 points
# - …
# - Accuracy on test set ≥ 78% : 15 points
#
# To get the remaining 5 points you should be able also justify your choices (e.g., “I used Dropout because … and hence I have increased epochs as I noted …”).
#
# **Note:** Transfer learning is **not allowed** — otherwise you can complete this exercise easily, and it is not useful for educational purposes.

# %%
class Model(nn.Module):
    def __init__(self, channels=3, height=32, width=32, drop_prob1=0.3, drop_prob2=0.4, drop_prob_fc=0.5):
        super().__init__()
        
        conv1 = nn.Conv2d(channels, 32, kernel_size=5, padding=2)
        h_out, w_out = out_dimensions(conv1, height, width)
        pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        h_out, w_out = out_dimensions(conv2, h_out, w_out)
        pool2 = nn.AvgPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        dropout1 = nn.Dropout2d(drop_prob1)
        
        conv3 = nn.Conv2d(32, 20, kernel_size=3, padding=1)
        h_out, w_out = out_dimensions(conv3, h_out, w_out)
        pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        dropout2 = nn.Dropout2d(drop_prob2)
        
        self.conv_seq = nn.Sequential(conv1, pool1, nn.ReLU(), dropout1, conv2, pool2, nn.ReLU(), dropout2, conv3, pool3, nn.ReLU())
        
        self.fc1 = nn.Linear(20 * h_out * w_out, out_features=120)
        self.fc2 = nn.Linear(120, out_features=10)
        self.dropout_fc = nn.Dropout(drop_prob_fc)
        
        self.dimensions_final = (20, h_out, w_out)
        
    def forward(self, x):
        x = self.conv_seq(x)
        
        n_channels, h, w = self.dimensions_final
        x = x.view(-1, n_channels * h * w)
        x = F.relu(self.fc1(x))
        x = self.dropout_fc(x)
        x = self.fc2(x)
        
        return x

print(Model(3, 32))
print(Model(3, 32).dimensions_final)

# Init
model = Model(3, 32)
early_stop = EarlyStopping(patience=10, min_delta=0.01)
learning_rate = 0.035
batch_size = 32
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss()
print(model.dimensions_final)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'mps' 
    if torch.backends.mps.is_available() else 'cpu')
model = model.to(DEVICE)
print("Working on", DEVICE)

train_loader = DataLoader(dataset_train, batch_size=batch_size, pin_memory=True, num_workers=2)
validation_loader = DataLoader(dataset_validation, batch_size=len(dataset_validation), pin_memory=True, num_workers=2)
test_loader = DataLoader(dataset_test, batch_size=len(dataset_test), pin_memory=True, num_workers=2)

# Training Loop
n_epochs = 8
logging_interval = 250
model, train_loss_list, train_acc_list, val_loss_list, val_acc_list = fit(model, logging_interval=logging_interval)

# Final test evaluation
_, test_acc = evaluate_model(model, test_loader, loss_fn)
print(f"\nTest Accuracy: {test_acc:.2f}%")
# Out:
# Model(
#   (conv_seq): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Dropout2d(p=0.3, inplace=False)
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (6): ReLU()
#     (7): Dropout2d(p=0.4, inplace=False)
#     (8): Conv2d(32, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): ReLU()
#   )
#   (fc1): Linear(in_features=320, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=10, bias=True)
#   (dropout_fc): Dropout(p=0.5, inplace=False)
# )
# (20, 4, 4)
# (20, 4, 4)
# Working on cuda
# Epoch 1, Step 250: Training Loss: 2.2586, Training Accuracy: 14.10% | Val Loss: 2.0926, Val Accuracy: 23.14%
# Epoch 1, Step 500: Training Loss: 2.1057, Training Accuracy: 22.84% | Val Loss: 1.9836, Val Accuracy: 29.90%
# Epoch 1, Step 750: Training Loss: 1.9971, Training Accuracy: 27.01% | Val Loss: 1.8520, Val Accuracy: 34.92%
# Epoch 1, Step 1000: Training Loss: 1.8979, Training Accuracy: 31.24% | Val Loss: 1.7533, Val Accuracy: 37.38%
# Epoch 1, Step 1250: Training Loss: 1.8553, Training Accuracy: 32.29% | Val Loss: 1.6879, Val Accuracy: 39.36%
# Epoch 1, Step 1500: Training Loss: 1.8096, Training Accuracy: 34.21% | Val Loss: 1.6465, Val Accuracy: 40.14%
# Epoch 1, Step 1563: Train Loss: 1.7809, Train Acc: 34.21% | Val Loss: 1.6359, Val Acc: 41.38%
# Epoch 2, Step 250: Training Loss: 1.7445, Training Accuracy: 36.04% | Val Loss: 1.5738, Val Accuracy: 42.16%
# Epoch 2, Step 500: Training Loss: 1.7373, Training Accuracy: 36.71% | Val Loss: 1.5738, Val Accuracy: 43.70%
# Epoch 2, Step 750: Training Loss: 1.6821, Training Accuracy: 38.62% | Val Loss: 1.5077, Val Accuracy: 45.38%
# Epoch 2, Step 1000: Training Loss: 1.6596, Training Accuracy: 39.35% | Val Loss: 1.5067, Val Accuracy: 44.96%
# Epoch 2, Step 1250: Training Loss: 1.6594, Training Accuracy: 39.50% | Val Loss: 1.4971, Val Accuracy: 45.40%
# Epoch 2, Step 1500: Training Loss: 1.6300, Training Accuracy: 40.38% | Val Loss: 1.4701, Val Accuracy: 46.90%
# Epoch 2, Step 1563: Train Loss: 1.6031, Train Acc: 40.38% | Val Loss: 1.4504, Val Acc: 46.82%
# Epoch 3, Step 250: Training Loss: 1.5937, Training Accuracy: 42.10% | Val Loss: 1.4344, Val Accuracy: 47.98%
# Epoch 3, Step 500: Training Loss: 1.6182, Training Accuracy: 41.85% | Val Loss: 1.4447, Val Accuracy: 48.18%
# Epoch 3, Step 750: Training Loss: 1.5436, Training Accuracy: 43.88% | Val Loss: 1.3990, Val Accuracy: 49.34%
# Epoch 3, Step 1000: Training Loss: 1.5328, Training Accuracy: 44.48% | Val Loss: 1.3973, Val Accuracy: 49.60%
# Epoch 3, Step 1250: Training Loss: 1.5584, Training Accuracy: 43.25% | Val Loss: 1.3677, Val Accuracy: 50.40%
# Epoch 3, Step 1500: Training Loss: 1.5292, Training Accuracy: 45.05% | Val Loss: 1.3605, Val Accuracy: 51.38%
# Epoch 3, Step 1563: Train Loss: 1.5242, Train Acc: 45.05% | Val Loss: 1.4007, Val Acc: 48.86%
# Epoch 4, Step 250: Training Loss: 1.5159, Training Accuracy: 44.62% | Val Loss: 1.3426, Val Accuracy: 51.20%
# Epoch 4, Step 500: Training Loss: 1.5159, Training Accuracy: 45.71% | Val Loss: 1.3417, Val Accuracy: 53.08%
# Epoch 4, Step 750: Training Loss: 1.4758, Training Accuracy: 46.15% | Val Loss: 1.3147, Val Accuracy: 53.22%
# Epoch 4, Step 1000: Training Loss: 1.4677, Training Accuracy: 46.70% | Val Loss: 1.3132, Val Accuracy: 53.02%
# Epoch 4, Step 1250: Training Loss: 1.4875, Training Accuracy: 45.59% | Val Loss: 1.2899, Val Accuracy: 53.16%
# Epoch 4, Step 1500: Training Loss: 1.4645, Training Accuracy: 47.19% | Val Loss: 1.2794, Val Accuracy: 54.24%
# Epoch 4, Step 1563: Train Loss: 1.4196, Train Acc: 47.19% | Val Loss: 1.2750, Val Acc: 53.66%
# Epoch 5, Step 250: Training Loss: 1.4413, Training Accuracy: 48.01% | Val Loss: 1.2455, Val Accuracy: 54.96%
# Epoch 5, Step 500: Training Loss: 1.4522, Training Accuracy: 47.71% | Val Loss: 1.2694, Val Accuracy: 55.62%
# Epoch 5, Step 750: Training Loss: 1.4070, Training Accuracy: 48.73% | Val Loss: 1.2402, Val Accuracy: 55.26%
# Epoch 5, Step 1000: Training Loss: 1.3971, Training Accuracy: 49.81% | Val Loss: 1.2509, Val Accuracy: 54.80%
# Epoch 5, Step 1250: Training Loss: 1.4327, Training Accuracy: 47.84% | Val Loss: 1.2594, Val Accuracy: 55.54%
# Epoch 5, Step 1500: Training Loss: 1.4008, Training Accuracy: 49.09% | Val Loss: 1.2155, Val Accuracy: 56.66%
# Epoch 5, Step 1563: Train Loss: 1.3684, Train Acc: 49.09% | Val Loss: 1.2573, Val Acc: 54.90%
# Epoch 6, Step 250: Training Loss: 1.3954, Training Accuracy: 49.02% | Val Loss: 1.2026, Val Accuracy: 57.28%
# Epoch 6, Step 500: Training Loss: 1.3995, Training Accuracy: 49.90% | Val Loss: 1.2060, Val Accuracy: 58.34%
# Epoch 6, Step 750: Training Loss: 1.3574, Training Accuracy: 51.49% | Val Loss: 1.1886, Val Accuracy: 57.08%
# Epoch 6, Step 1000: Training Loss: 1.3423, Training Accuracy: 51.81% | Val Loss: 1.2008, Val Accuracy: 56.80%
# Epoch 6, Step 1250: Training Loss: 1.3871, Training Accuracy: 49.80% | Val Loss: 1.2067, Val Accuracy: 56.86%
# Epoch 6, Step 1500: Training Loss: 1.3679, Training Accuracy: 50.40% | Val Loss: 1.1617, Val Accuracy: 58.68%
# Epoch 6, Step 1563: Train Loss: 1.3328, Train Acc: 50.40% | Val Loss: 1.2213, Val Acc: 55.72%
# Epoch 7, Step 250: Training Loss: 1.3522, Training Accuracy: 51.86% | Val Loss: 1.1498, Val Accuracy: 58.80%
# Epoch 7, Step 500: Training Loss: 1.3580, Training Accuracy: 51.10% | Val Loss: 1.1480, Val Accuracy: 59.50%
# Epoch 7, Step 750: Training Loss: 1.3298, Training Accuracy: 52.16% | Val Loss: 1.1428, Val Accuracy: 58.58%
# Epoch 7, Step 1000: Training Loss: 1.3137, Training Accuracy: 52.61% | Val Loss: 1.1694, Val Accuracy: 58.12%
# Epoch 7, Step 1250: Training Loss: 1.3570, Training Accuracy: 51.39% | Val Loss: 1.1713, Val Accuracy: 59.10%
# Epoch 7, Step 1500: Training Loss: 1.3253, Training Accuracy: 52.25% | Val Loss: 1.1663, Val Accuracy: 57.42%
# Epoch 7, Step 1563: Train Loss: 1.3048, Train Acc: 52.25% | Val Loss: 1.1766, Val Acc: 58.28%
# Epoch 8, Step 250: Training Loss: 1.3209, Training Accuracy: 53.05% | Val Loss: 1.1205, Val Accuracy: 59.82%
# Epoch 8, Step 500: Training Loss: 1.3292, Training Accuracy: 52.55% | Val Loss: 1.1262, Val Accuracy: 60.40%
# Epoch 8, Step 750: Training Loss: 1.3021, Training Accuracy: 52.80% | Val Loss: 1.1126, Val Accuracy: 59.92%
# Epoch 8, Step 1000: Training Loss: 1.2912, Training Accuracy: 54.01% | Val Loss: 1.1129, Val Accuracy: 60.18%
# Epoch 8, Step 1250: Training Loss: 1.3236, Training Accuracy: 52.73% | Val Loss: 1.1106, Val Accuracy: 60.74%
# Epoch 8, Step 1500: Training Loss: 1.3091, Training Accuracy: 52.96% | Val Loss: 1.1190, Val Accuracy: 59.76%
# Epoch 8, Step 1563: Train Loss: 1.2848, Train Acc: 52.96% | Val Loss: 1.1091, Val Acc: 60.26%
# Epoch 9, Step 250: Training Loss: 1.2923, Training Accuracy: 53.66% | Val Loss: 1.0890, Val Accuracy: 60.56%
# Epoch 9, Step 500: Training Loss: 1.3155, Training Accuracy: 53.35% | Val Loss: 1.0955, Val Accuracy: 60.88%
# Epoch 9, Step 750: Training Loss: 1.2749, Training Accuracy: 54.52% | Val Loss: 1.0946, Val Accuracy: 60.46%
# Epoch 9, Step 1000: Training Loss: 1.2719, Training Accuracy: 54.34% | Val Loss: 1.0835, Val Accuracy: 61.66%
# Epoch 9, Step 1250: Training Loss: 1.3036, Training Accuracy: 54.04% | Val Loss: 1.0973, Val Accuracy: 60.96%
# Epoch 9, Step 1500: Training Loss: 1.2760, Training Accuracy: 55.19% | Val Loss: 1.1022, Val Accuracy: 60.82%
# Epoch 9, Step 1563: Train Loss: 1.2813, Train Acc: 55.19% | Val Loss: 1.0784, Val Acc: 61.72%
# Epoch 10, Step 250: Training Loss: 1.2651, Training Accuracy: 55.05% | Val Loss: 1.0720, Val Accuracy: 61.92%
# Epoch 10, Step 500: Training Loss: 1.2720, Training Accuracy: 54.54% | Val Loss: 1.0792, Val Accuracy: 61.98%
# Epoch 10, Step 750: Training Loss: 1.2646, Training Accuracy: 54.92% | Val Loss: 1.0983, Val Accuracy: 60.90%
# Epoch 10, Step 1000: Training Loss: 1.2335, Training Accuracy: 55.99% | Val Loss: 1.0737, Val Accuracy: 61.54%
# Epoch 10, Step 1250: Training Loss: 1.2720, Training Accuracy: 54.26% | Val Loss: 1.0692, Val Accuracy: 62.32%
# Epoch 10, Step 1500: Training Loss: 1.2537, Training Accuracy: 55.09% | Val Loss: 1.0514, Val Accuracy: 63.04%
# Epoch 10, Step 1563: Train Loss: 1.2742, Train Acc: 55.09% | Val Loss: 1.0653, Val Acc: 62.66%
#
# Test Accuracy: 62.18%

# %%
plt.figure(figsize=(10, 7))
steps = [x * logging_interval for x in range(len(train_loss_list))]
plt.plot(steps, train_loss_list, label='Training Loss')
plt.plot(steps, val_loss_list, label='Validation Loss')
plt.title("CIFER10")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task 9 (10 pts)
#
# Until now, we asked you to keep the seed fixed.
# Train **the model you defined at Task 5** five times with 5 different seeds (already specified below, **don't change them**), each for the same number of epochs epochs.
# Don't change other hyperparameters. Observe the accuracy of the test set in each case. What can you say?

# %%
test_accs = []
for seed in range(5):
    torch.manual_seed(seed)
    print(f"Testing seed {seed}", flush = True)
    
    # init
    model = Model_OG(3, 32)
    early_stop = EarlyStopping(patience=10, min_delta=0.01)
    learning_rate = 0.03
    batch_size = 32
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    loss_fn = nn.CrossEntropyLoss()
    print(model.dimensions_final)

    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'mps' 
        if torch.backends.mps.is_available() else 'cpu')
    model = model.to(DEVICE)
    print("Working on", DEVICE)
    
    # Training loop
    n_epochs = 5
    logging_interval = len(train_loader)
    model, = fit(model, logging_interval=logging_interval)

    # Final test evaluation
    _, test_acc = evaluate_model(model, test_loader, loss_fn)
    test_accs.append(test_acc)
    print(f"\nTest Accuracy: {test_acc:.2f}%")
# Out:
# Testing seed 0
# (20, 4, 4)
# Working on cuda
# Epoch 1, Step 1563: Training Loss: 1.7426, Training Accuracy: 36.54% | Val Loss: 1.6884, Val Accuracy: 38.74%
# Epoch 2, Step 1563: Training Loss: 1.3252, Training Accuracy: 52.71% | Val Loss: 1.4922, Val Accuracy: 47.70%
# Epoch 3, Step 1563: Training Loss: 1.1316, Training Accuracy: 59.70% | Val Loss: 1.2727, Val Accuracy: 56.22%
# Epoch 4, Step 1563: Training Loss: 1.0015, Training Accuracy: 64.59% | Val Loss: 1.1117, Val Accuracy: 61.80%
# Epoch 5, Step 1563: Training Loss: 0.9068, Training Accuracy: 68.07% | Val Loss: 1.0365, Val Accuracy: 64.94%
#
# Test Accuracy: 64.68%
# Testing seed 1
# (20, 4, 4)
# Working on cuda
# Epoch 1, Step 1563: Training Loss: 1.7495, Training Accuracy: 36.00% | Val Loss: 1.4902, Val Accuracy: 45.22%
# Epoch 2, Step 1563: Training Loss: 1.3263, Training Accuracy: 52.68% | Val Loss: 1.2678, Val Accuracy: 54.54%
# Epoch 3, Step 1563: Training Loss: 1.1347, Training Accuracy: 59.72% | Val Loss: 1.1248, Val Accuracy: 60.34%
# Epoch 4, Step 1563: Training Loss: 0.9951, Training Accuracy: 64.96% | Val Loss: 1.0398, Val Accuracy: 64.08%
# Epoch 5, Step 1563: Training Loss: 0.8998, Training Accuracy: 68.45% | Val Loss: 0.9550, Val Accuracy: 67.04%
#
# Test Accuracy: 66.26%
# Testing seed 2
# (20, 4, 4)
# Working on cuda
# Epoch 1, Step 1563: Training Loss: 1.7468, Training Accuracy: 36.03% | Val Loss: 1.7114, Val Accuracy: 37.96%
# Epoch 2, Step 1563: Training Loss: 1.3347, Training Accuracy: 52.16% | Val Loss: 1.3946, Val Accuracy: 50.90%
# Epoch 3, Step 1563: Training Loss: 1.1385, Training Accuracy: 59.73% | Val Loss: 1.1516, Val Accuracy: 60.12%
# Epoch 4, Step 1563: Training Loss: 1.0128, Training Accuracy: 64.32% | Val Loss: 1.1293, Val Accuracy: 60.32%
# Epoch 5, Step 1563: Training Loss: 0.9236, Training Accuracy: 67.63% | Val Loss: 1.0275, Val Accuracy: 63.96%
#
# Test Accuracy: 63.94%
# Testing seed 3
# (20, 4, 4)
# Working on cuda
# Epoch 1, Step 1563: Training Loss: 1.7882, Training Accuracy: 34.61% | Val Loss: 1.5669, Val Accuracy: 41.50%
# Epoch 2, Step 1563: Training Loss: 1.3553, Training Accuracy: 51.50% | Val Loss: 1.4417, Val Accuracy: 49.26%
# Epoch 3, Step 1563: Training Loss: 1.1667, Training Accuracy: 58.71% | Val Loss: 1.2090, Val Accuracy: 58.88%
# Epoch 4, Step 1563: Training Loss: 1.0244, Training Accuracy: 64.09% | Val Loss: 1.1279, Val Accuracy: 61.42%
# Epoch 5, Step 1563: Training Loss: 0.9214, Training Accuracy: 67.87% | Val Loss: 0.9463, Val Accuracy: 66.78%
#
# Test Accuracy: 67.34%
# Testing seed 4
# (20, 4, 4)
# Working on cuda
# Epoch 1, Step 1563: Training Loss: 1.8056, Training Accuracy: 33.95% | Val Loss: 1.6081, Val Accuracy: 39.74%
# Epoch 2, Step 1563: Training Loss: 1.3579, Training Accuracy: 51.42% | Val Loss: 1.4606, Val Accuracy: 47.20%
# Epoch 3, Step 1563: Training Loss: 1.1615, Training Accuracy: 59.01% | Val Loss: 1.2485, Val Accuracy: 56.16%
# Epoch 4, Step 1563: Training Loss: 1.0250, Training Accuracy: 63.74% | Val Loss: 1.1105, Val Accuracy: 61.70%
# Epoch 5, Step 1563: Training Loss: 0.9256, Training Accuracy: 67.48% | Val Loss: 1.0295, Val Accuracy: 64.04%
#
# Test Accuracy: 63.60%

# %%
plt.scatter(range(5), test_accs, c="b")
plt.xlabel("Seed")
plt.ylabel("Test acc")
plt.ylim(min(test_accs) - 5, max(test_accs) + 5)
plt.grid(True, ls=':')
plt.xticks(range(5))
plt.show()

# %% [markdown]
# ## Questions
#
# During the presentation, we may ask questions to ensure you have understood the core concepts of the course. Examples include:
# 1. Where are the parameters that a CNN learns during training?
# 2. Why do we use convolutional layers instead of fully connected layers for image data?
# 3. What is the role of pooling layers? What would happen if we removed them?
# 4. What is Dropout? Batch Normalizaton? Do you have other regularization tecniques in mind?
