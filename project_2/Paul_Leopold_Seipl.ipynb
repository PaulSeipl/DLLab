# %% [markdown]
# # Mini Project 2
#
# By the deadline, please submit the provided Jupyter notebook with all/some required tasks completed and clearly solved. Make sure your code is neat, well-commented, and that all outputs are visible (run all cells before saving). Notebooks with missing tasks or unexecuted cells may receive fewer points. After you submit, you won’t be able to make changes, so double-check your work and be sure to start from the provided template
#
# ## Submission rules
# As already discussed in class, we will stick to the following rules.
# - Use the templates and name your files `NAME_SURNAME.ipynb` (If you have more than one name, just concatenate them). We will compare what you present with that file.
# - Code either not written in Python or not using PyTorch receives a grade of 0. Of course, you can use auxiliary packages when needed (`matplotlib`, `numpy`, ...), but for the learning part, you must use PyTorch.
# -  If plagiarism is suspected, TAs and I will thoroughly investigate the situation, and we will summon the student for a face-to-face clarification regarding certain answers they provided. In case of plagiarism, a score reduction will be applied to all the people involved, depending on their level of involvement.
# -  If extensive usage of AI tools is detected, we will summon the student for a face-to-face clarification regarding certain answers they provided. If the answers are not adequately supported with in-person answers, we will proceed to apply a penalty to the evaluation, ranging from 10% to 100%.

# %%
import matplotlib.pyplot as plt
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
from torch.utils.data import DataLoader

# %% [markdown]
# ## Image classification uning a CNN
#
# The CIFAR-10 dataset is a widely used collection of images in the field of computer vision. It consists of 60000 (50000 for the training and 10000 for the test) 32x32 color images across 10 different classes, with each class containing 6,000 images. These classes include common objects such as airplanes, automobiles, cats, and dogs. CIFAR-10 serves as a benchmark for image classification tasks and has been instrumental in developing and evaluating machine learning algorithms for image recognition.
# The task of this assignment is to classify the images

# %% [markdown]
# ### Task 0 (0 pts)
# Understand what's going on in the two cells below. Do the following experiments:
# 1. Run the first and the second cell in a row.
# 2. Run the first cell and two times in a row the second one.
#
# What do you observe? We don't need any answer, but please just keep this phenomenon in mind.

# %%
torch.manual_seed(0)

# %%
torch.randint(1, 10 , (1,1))
# Out:
# tensor([[9]])

# %% [markdown]
# Now, we'll set a seed that will remain the same for all the code below

# %% [markdown]
# ### Task 1 (2.5 pts)
# Load the [data (You can do it directly in PyTorch)](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html) and take some time to inspect the dataset. Report here at least one image per class and a histogram of the distribution of the images of the training and test set.

# %%
# download training data
dataset_train = torchvision.datasets.CIFAR10('./cifar10', train=True, download=True)
dataset_test = torchvision.datasets.CIFAR10('./cifar10', train=False, download=True)

# %%
# print basic information
print(dataset_train)
print(dataset_train[0])
print("Classes: ", dataset_train.classes)
print(f"There are {len(dataset_train)} for training and {len(dataset_test)} for testing.")

# get one image of each class
samples = {}
for img, label in dataset_train:
    if label not in samples:
        samples[label] = img
    if len(samples) == len(dataset_train.classes):
        break

# show images with corresponding label
fig, axs = plt.subplots(2, len(dataset_train.classes)//2)
for ax, label_ix, img in zip(axs.flatten(), samples.keys(), samples.values()):
    ax.imshow(img)
    ax.set_title(dataset_train.classes[label_ix])
    ax.set_axis_off()

fig.set_size_inches(10, 4)
plt.show()
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./cifar10
#     Split: Train
# (<PIL.Image.Image image mode=RGB size=32x32 at 0x79AA4070B990>, 6)
# Classes:  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# There are 50000 for training and 10000 for testing.

# %%
# display histogram of training and test dataset
get_labels = lambda dataset: [data[1] for data in dataset]
bins = len(dataset_train.classes)
plt.hist([get_labels(dataset_train), get_labels(dataset_test)], label=['train', 'test'])
plt.legend(loc='best')
plt.xticks(range(len(dataset_train.classes)))
plt.show()

# %% [markdown]
# ### Task 2 (2.5 pts)
# Are the entries in the correct type for the DL framework in PyTorch? How can you arrive at a suitable format for your training pipeline? Be sure to have understood
# - The type of each element of the dataset
# - How we can convert it to a suitable type.
# - The dimension of the image as a `torch.Tensor` object
# - The meaning of each dimension of the images

# %%
# add transformer to datasets to get images as tensors
dataset_train.transform = transforms.ToTensor()
dataset_test.transform = transforms.ToTensor()

# %% [markdown]
# ### Task 3 (10 pts)
# When you arrive at this question you should have each entry as a `torch.Tensor` of shape (3,32, 32) and clear the meaning of each dimension. A good practice in DL is to work with features having mean 0 and standard deviation equal to 1. Convert the dataset of the images in this format. To do so, you can do it from scratch (not recommended) or use the function [`torchvision.transforms.Normalize`](https://pytorch.org/vision/0.8/transforms.html\#torchvision.transforms.Normalize). If you go for this second option, don't forget that we have already transformed our dataset in the previous point, hence, it could be of help using the function [`transforms.Compose`](https://pytorch.org/vision/0.8/transforms.html\#torchvision.transforms.Compose). You can see an example in the tutorial linked above.
#
# **Note** that the usage of the function is tricky: try to really understand what's going on

# %%
# calculate std and mean of each channel
def get_std_mean(dataset, batch_size=None):
    batch_size = batch_size if batch_size else len(dataset_test)
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
    all_images = next(iter(loader))[0]
    return torch.std_mean(all_images, dim=[0, 2, 3])

# %%
stds_train, means_train = get_std_mean(dataset_train)
stds_test, means_test = get_std_mean(dataset_test)
print("Calculated mean train:", means_train)
print("Calculated std train:", stds_train)
# Out:
# Calculated mean train: tensor([0.4935, 0.4834, 0.4472])
# Calculated std train: tensor([0.2476, 0.2446, 0.2626])

# %%
# update transform to include normalization with computed means/stds
dataset_train.transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(means_train, stds_train)]
)
dataset_test.transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(means_test, stds_test)]
)

print("shape: ", dataset_train[0][0].shape, "dtype: ", dataset_train[0][0].dtype)
# Out:
# shape:  torch.Size([3, 32, 32]) dtype:  torch.float32

# %%
# Recalculate mean and std after normalization to verify
stds, means = get_std_mean(dataset_train, batch_size=5000)
print("Mean after normalization (should be ~0):", means)
print("Std after normalization (should be ~1):", stds)
# Out:
# Mean after normalization (should be ~0): tensor([-0.0089, -0.0080, -0.0103])
# Std after normalization (should be ~1): tensor([0.9999, 0.9996, 1.0005])

# %% [markdown]
# ### Task 4 (1 pts)
# As you might have observed, we only have a train and test set. We need a validation set for hyperparameter tuning. Create a validation set by splitting the test set.

# %%
dataset_validation, dataset_test = torch.utils.data.random_split(dataset_test, [0.5, 0.5])

# %% [markdown]
# ### Task 5 (20 pts)
# Starting from the code provided during Lecture 6, define a ConvNet. You can **only** use:
#
# - Convolutional layers
# - Max/Avg Pooling layers
# - Activation Functions
# - Fully connected layers
#
# Note that the choice `Conv - Pool - Conv` is not mandatory. Have you tried `Conv - Conv - Activ - Pool - Conv - Conv - Activ - Pool - FC`?
# For each convolutional layer you can choose padding and stride. Be prepared on comment on the choices of the dimensions of the layers.

# %%
from math import floor

def out_dimensions(conv_layer, h_in, w_in):
    '''
    This function computes the output dimension of each convolutional layers in the most general way. 
    See here https://docs.pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
    '''
    h_out = floor((h_in + 2 * conv_layer.padding[0] - conv_layer.dilation[0] * (conv_layer.kernel_size[0] - 1) - 1) /
                  conv_layer.stride[0] + 1)
    w_out = floor((w_in + 2 * conv_layer.padding[1] - conv_layer.dilation[1] * (conv_layer.kernel_size[1] - 1) - 1) /
                  conv_layer.stride[1] + 1)
    return h_out, w_out

class Model_OG(nn.Module):
    def __init__(self, channels=3, height=32, width=32):
        super().__init__()
        
        conv1 = nn.Conv2d(channels, 32, kernel_size=5, padding=2)
        h_out, w_out = out_dimensions(conv1, height, width)
        pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        h_out, w_out = out_dimensions(conv2, h_out, w_out)
        pool2 = nn.AvgPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        
        conv3 = nn.Conv2d(32, 20, kernel_size=3, padding=1)
        h_out, w_out = out_dimensions(conv3, h_out, w_out)
        pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2
        
        self.conv_seq = nn.Sequential(conv1, pool1, nn.ReLU(), conv2, pool2, nn.ReLU(), conv3, pool3, nn.ReLU())
        
        self.fc1 = nn.Linear(20 * h_out * w_out, out_features=120)
        self.fc2 = nn.Linear(120, out_features=10)
        
        self.dimensions_final = (20, h_out, w_out)
        
    def forward(self, x):
        x = self.conv_seq(x)
        
        n_channels, h, w = self.dimensions_final
        x = x.view(-1, n_channels * h * w)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        
        return x

print(Model_OG(3, 32))
print(Model_OG(3, 32).dimensions_final)
# Out:
# Model_OG(
#   (conv_seq): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (5): ReLU()
#     (6): Conv2d(32, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU()
#   )
#   (fc1): Linear(in_features=320, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=10, bias=True)
# )
# (20, 4, 4)

# %% [markdown]
# ### Task 6 (35 pts)
# Implement the training pipeline. Make sure to code the following:
#
# - Print and record the current training loss and accuracy every *n* steps (choose *n*)
# - Print and record the current validation loss and accuracy every *n* steps (choose *n*)
#
# The validation loss will help you in hyperparameter tuning. Train your model.
# With my choice of hyperparameters, the best test accuracy is above **65%**, hence, a necessary condition to get full marks is to achieve an accuracy on the test set greater or equal to **65%**.
#
# You may want to follow some of these hints (**They are, of course, dependent on the architecture, optimizer, ...**):
#
# - 5 epochs should be enough
# - Batch size = 32 could be a good starting point
# - A learning rate around 0.03 should be a good tradeoff between speed and stability
# - SGD should be a good optimizer
#
# Be prepared to answer the following questions:
# - Why that learning rate? Why not higher/smaller?
# - Number of epochs: Why that number?
# - Some comments on your architecture: why that deep? why not deeper? why not smaller?

# %%
import copy

class EarlyStopping():
    def __init__(self, patience=5, min_delta=0, restore_best_weights=True):
        self.patience = patience
        self.min_delta = min_delta # minimum improvement to reset patience
        self.restore_best_weights = restore_best_weights
        self.best_model = None
        self.best_loss = None
        self.counter = 0
        self.status = ""
        
    def __call__(self, model, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.best_model = copy.deepcopy(model)
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
            self.best_model.load_state_dict(model.state_dict())
        elif self.best_loss - val_loss < self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.status = f"Stopped on {self.counter}"
                if self.restore_best_weights:
                    model.load_state_dict(self.best_model.state_dict())
                return True
        self.status = f"{self.counter}/{self.patience}"
        return False

# %%
model = Model_OG(3, 32)
early_stop = EarlyStopping(patience=10, min_delta=0.01)
learning_rate = 0.03
batch_size = 32
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss()
print(model.dimensions_final)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'mps' 
    if torch.backends.mps.is_available() else 'cpu')
model = model.to(DEVICE)
print("Working on", DEVICE)
# Out:
# (20, 4, 4)
# Working on cuda

# %%
train_loader = DataLoader(dataset_train, batch_size=batch_size, pin_memory=True, num_workers=2)
validation_loader = DataLoader(dataset_validation, batch_size=len(dataset_validation), pin_memory=True, num_workers=2)
test_loader = DataLoader(dataset_test, batch_size=len(dataset_test), pin_memory=True, num_workers=2)

# %%
def evaluate_model(model, data_loader, loss_fn):
    model.eval()
    total_loss = 0
    n_correct = 0
    n_samples = 0
    
    for data, target in data_loader: # Just one batch
            data, target = data.to(DEVICE), target.to(DEVICE)
            # Make a prediction
            output = model(data)
            # Compute the loss function
            total_loss += loss_fn(output, target).item()
            # Compute the accuracy
            _, predicted = torch.max(output.data, 1)
            n_samples += target.size(0)
            n_correct += (predicted == target).sum().item()
        
    avg_loss = total_loss / len(data_loader)
    accuracy = 100.0 * n_correct / n_samples
    return avg_loss, accuracy

# %%
def fit(model, epochs=5, logging_interval=250):
    train_loss_list = []
    train_acc_list = []
    val_loss_list = []
    val_acc_list = []
    for epoch in range(epochs):
        n_correct = 0
        n_samples = 0
        loss_train = 0
        for step, (data, target) in enumerate(train_loader):
            # Set the model in training mode
            model.train()
            data, target = data.to(DEVICE), target.to(DEVICE)
            # Set the gradient to 0
            optimizer.zero_grad()
            # Make a prediction
            output = model(data)
            # Compute the loss function
            loss = loss_fn(output, target)
            loss_train += loss.item()
            # Backpropagation
            loss.backward()
            # Update parameters
            optimizer.step()
            # Compute the training accuracy
            _, predicted = torch.max(output.data, 1)
            n_samples += target.size(0)
            n_correct += (predicted == target).sum().item()
            # Log every logging_interval steps train and validation loss and accuracy
            if (step + 1) % logging_interval == 0:
                # Calculate avg train loss and acc over last steps
                avg_loss_train = loss_train / logging_interval
                avg_train_acc = 100.0 * n_correct / n_samples
                # Validate
                val_loss, val_acc = evaluate_model(model, validation_loader, loss_fn)
                
                print(f"Epoch {epoch+1}, Step {step+1}: " 
                    f"Training Loss: {avg_loss_train:.4f}, Training Accuracy: {avg_train_acc:.2f}% | "
                    f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.2f}%")
                
                train_loss_list.append(avg_loss_train)
                train_acc_list.append(avg_train_acc)
                val_loss_list.append(val_loss)
                val_acc_list.append(val_acc)
                # Reset
                loss_train, n_samples, n_correct = 0, 0, 0
                
                    # Early stopping check
                if early_stop(model, val_loss):
                    print(f"Stopped trained at epoch {epoch}")
                    break
                
        # Log remaining batches
        remainder = (step + 1) % logging_interval
        if remainder != 0:
            avg_loss_train = loss_train / remainder
            avg_train_acc = 100.0 * n_correct / n_samples
            val_loss, val_acc = evaluate_model(model, validation_loader, loss_fn)
            
            print(f"Epoch {epoch+1}, Step {step+1}: "
                f"Train Loss: {avg_loss_train:.4f}, Train Acc: {avg_train_acc:.2f}% | "
                f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
            
            train_loss_list.append(avg_loss_train)
            train_acc_list.append(avg_train_acc)
            val_loss_list.append(val_loss)
            val_acc_list.append(val_acc)
        
    return model, train_loss_list, train_acc_list, val_loss_list, val_acc_list

# %%
# Final test evaluation
logging_interval = 250
model, train_loss_list, train_acc_list, val_loss_list, val_acc_list = fit(model, logging_interval=logging_interval)
_, test_acc = evaluate_model(model, test_loader, loss_fn)
print(f"\nTest Accuracy: {test_acc:.2f}%")
# Out:
# Epoch 1, Step 250: Training Loss: 2.1974, Training Accuracy: 18.16% | Val Loss: 2.0197, Val Accuracy: 25.28%
# Epoch 1, Step 500: Training Loss: 1.9427, Training Accuracy: 29.70% | Val Loss: 1.8547, Val Accuracy: 32.82%
# Epoch 1, Step 750: Training Loss: 1.7411, Training Accuracy: 37.04% | Val Loss: 1.6327, Val Accuracy: 40.72%
# Epoch 1, Step 1000: Training Loss: 1.6246, Training Accuracy: 41.09% | Val Loss: 1.5636, Val Accuracy: 43.20%
# Epoch 1, Step 1250: Training Loss: 1.5630, Training Accuracy: 43.36% | Val Loss: 1.5039, Val Accuracy: 45.04%
# Epoch 1, Step 1500: Training Loss: 1.5083, Training Accuracy: 46.06% | Val Loss: 1.4245, Val Accuracy: 48.76%
# Epoch 1, Step 1563: Train Loss: 1.4704, Train Acc: 48.00% | Val Loss: 1.6142, Val Acc: 41.06%
# Epoch 2, Step 250: Training Loss: 1.4238, Training Accuracy: 48.74% | Val Loss: 1.3799, Val Accuracy: 50.48%
# Epoch 2, Step 500: Training Loss: 1.4027, Training Accuracy: 49.60% | Val Loss: 1.3768, Val Accuracy: 50.28%
# Epoch 2, Step 750: Training Loss: 1.3261, Training Accuracy: 52.90% | Val Loss: 1.3172, Val Accuracy: 53.00%
# Epoch 2, Step 1000: Training Loss: 1.2971, Training Accuracy: 53.29% | Val Loss: 1.3067, Val Accuracy: 52.90%
# Epoch 2, Step 1250: Training Loss: 1.2921, Training Accuracy: 54.11% | Val Loss: 1.2244, Val Accuracy: 55.70%
# Epoch 2, Step 1500: Training Loss: 1.2583, Training Accuracy: 55.44% | Val Loss: 1.1936, Val Accuracy: 57.78%
# Epoch 2, Step 1563: Train Loss: 1.2241, Train Acc: 57.05% | Val Loss: 1.3794, Val Acc: 51.24%
# Epoch 3, Step 250: Training Loss: 1.2016, Training Accuracy: 56.69% | Val Loss: 1.1749, Val Accuracy: 58.30%
# Epoch 3, Step 500: Training Loss: 1.2011, Training Accuracy: 58.15% | Val Loss: 1.1741, Val Accuracy: 58.06%
# Epoch 3, Step 750: Training Loss: 1.1425, Training Accuracy: 59.26% | Val Loss: 1.1602, Val Accuracy: 58.88%
# Epoch 3, Step 1000: Training Loss: 1.1278, Training Accuracy: 60.23% | Val Loss: 1.1214, Val Accuracy: 59.90%
# Epoch 3, Step 1250: Training Loss: 1.1214, Training Accuracy: 59.91% | Val Loss: 1.1159, Val Accuracy: 60.32%
# Epoch 3, Step 1500: Training Loss: 1.0942, Training Accuracy: 60.90% | Val Loss: 1.0788, Val Accuracy: 62.32%
# Epoch 3, Step 1563: Train Loss: 1.0708, Train Acc: 63.40% | Val Loss: 1.1334, Val Acc: 60.54%
# Epoch 4, Step 250: Training Loss: 1.0594, Training Accuracy: 62.49% | Val Loss: 1.1876, Val Accuracy: 58.94%
# Epoch 4, Step 500: Training Loss: 1.0616, Training Accuracy: 62.89% | Val Loss: 1.0472, Val Accuracy: 63.50%
# Epoch 4, Step 750: Training Loss: 1.0191, Training Accuracy: 64.09% | Val Loss: 1.0641, Val Accuracy: 62.52%
# Epoch 4, Step 1000: Training Loss: 0.9995, Training Accuracy: 65.64% | Val Loss: 1.0488, Val Accuracy: 62.80%
# Epoch 4, Step 1250: Training Loss: 0.9989, Training Accuracy: 64.33% | Val Loss: 1.0561, Val Accuracy: 63.28%
# Epoch 4, Step 1500: Training Loss: 0.9816, Training Accuracy: 64.88% | Val Loss: 0.9865, Val Accuracy: 65.32%
# Epoch 4, Step 1563: Train Loss: 0.9642, Train Acc: 66.50% | Val Loss: 1.0369, Val Acc: 64.30%
# Epoch 5, Step 250: Training Loss: 0.9554, Training Accuracy: 66.45% | Val Loss: 1.0946, Val Accuracy: 62.56%
# Epoch 5, Step 500: Training Loss: 0.9517, Training Accuracy: 66.45% | Val Loss: 0.9695, Val Accuracy: 66.32%
# Epoch 5, Step 750: Training Loss: 0.9254, Training Accuracy: 67.58% | Val Loss: 0.9958, Val Accuracy: 65.26%
# Epoch 5, Step 1000: Training Loss: 0.8992, Training Accuracy: 69.41% | Val Loss: 0.9835, Val Accuracy: 65.42%
# Epoch 5, Step 1250: Training Loss: 0.9122, Training Accuracy: 67.59% | Val Loss: 1.0292, Val Accuracy: 64.44%
# Epoch 5, Step 1500: Training Loss: 0.8940, Training Accuracy: 68.49% | Val Loss: 0.9240, Val Accuracy: 67.74%
# Epoch 5, Step 1563: Train Loss: 0.8782, Train Acc: 69.95% | Val Loss: 0.9730, Val Acc: 66.28%
#
# Test Accuracy: 66.46%

# %% [markdown]
# ### Task 7 (4 pts)
# Plot the evolution of the training and validation losses on the same graph. On the x-axis, you should preferably use the number of steps. Do you observe signs of overfitting or underfitting? Note that an improperly trained model will also result in a point deduction for the previous exercise.

# %%
plt.figure(figsize=(10, 7))
steps = [x * logging_interval for x in range(len(train_loss_list))]
plt.plot(steps, train_loss_list, label='Training Loss')
plt.plot(steps, val_loss_list, label='Validation Loss')
plt.title("CIFER10")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task 8 (20 pts)
# You may have noticed that it is quite likely to get overfitting in many cases, preventing it from going beyond 65% accuracy.
#
# Change the architecture as you like and try to increase the accuracy as much as possible. The base architecture must remain a ConvNet.
# Try any idea that comes to your mind but **justify it**.
#
# Some hints:
#
# - Add Dropout (Any other hyperparameter to tune?)
# - Change activation functions ([GeLU](https://arxiv.org/pdf/1606.08415v3.pdf) is known to work well with images)
# - Make your CNN deeper
# - Add some regularization techniques
# - Change the optimizer
# - Data augmentation
# - Batch normalization
# - …
#
# #### Points distribution:
#
# - Any successful try (test accuracy increase): 6 points
# - Accuracy on test set ≥ 70% : 7 points
# - Accuracy on test set ≥ 72% : 8 points
# - Accuracy on test set ≥ 73% : 9 points
# - …
# - Accuracy on test set ≥ 78% : 15 points
#
# To get the remaining 5 points you should be able also justify your choices (e.g., “I used Dropout because … and hence I have increased epochs as I noted …”).
#
# **Note:** Transfer learning is **not allowed** — otherwise you can complete this exercise easily, and it is not useful for educational purposes.

# %%
torch.cuda.empty_cache()
class Model(nn.Module):
    def __init__(self, channels=3, height=32, width=32, drop_prob1=0.2, drop_prob2=0.2, drop_prob_fc=0.2):
        super().__init__()

        conv1 = nn.Conv2d(channels, 32, kernel_size=5, padding=2)
        h_out, w_out = out_dimensions(conv1, height, width)
        pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2

        conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # Increase filters
        h_out, w_out = out_dimensions(conv2, h_out, w_out)
        pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2

        conv3 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        h_out, w_out = out_dimensions(conv3, h_out, w_out)
        pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        h_out, w_out = h_out // 2, w_out // 2

        self.conv_seq = nn.Sequential(
            conv1, nn.BatchNorm2d(32), nn.GELU(), pool1, nn.Dropout2d(drop_prob1),
            conv2, nn.BatchNorm2d(64), nn.GELU(), pool2, nn.Dropout2d(drop_prob1),
            conv3, nn.BatchNorm2d(64), nn.GELU(), pool3, nn.Dropout2d(drop_prob2)
        )

        self.fc1 = nn.Linear(64 * h_out * w_out, 256)  # Bigger FC layer
        self.fc2 = nn.Linear(256, 10)
        self.dropout_fc = nn.Dropout(drop_prob_fc)
        self.dimensions_final = (64, h_out, w_out)

    def forward(self, x):
        x = self.conv_seq(x)
        n_channels, h, w = self.dimensions_final
        x = x.view(-1, n_channels * h * w)
        x = F.gelu(self.fc1(x))
        x = self.dropout_fc(x)
        x = self.fc2(x)
        return x
    
class Model(nn.Module):
    def __init__(self, channels=3, height=32, width=32):
        super().__init__()
        
        # Block 1: 32x32 -> 16x16
        self.conv1 = nn.Sequential(
            nn.Conv2d(channels, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.GELU(),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.GELU(),
            nn.MaxPool2d(2)
        )
        
        # Block 2: 16x16 -> 8x8
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.GELU(),
            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.GELU(),
            nn.MaxPool2d(2)
        )
        
        # Block 3: 8x8 -> 4x4
        self.conv3 = nn.Sequential(
            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.GELU(),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.GELU(),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.GELU(),
            nn.MaxPool2d(2)
        )
        
        # Classifier
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(0.5),
            nn.Linear(256 * 4 * 4, 512),
            nn.GELU(),
            nn.Dropout(0.5),
            nn.Linear(512, 10)
        )
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.fc(x)
        return x


print(Model(3, 32))

def evaluate_model(model, data_loader, loss_fn):
    model.eval()
    total_loss = 0
    n_correct = 0
    n_samples = 0
    
    with torch.no_grad():  # Add this to save memory
        for data, target in data_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)
            total_loss += loss_fn(output, target).item() * data.size(0)
            _, predicted = torch.max(output.data, 1)
            n_samples += target.size(0)
            n_correct += (predicted == target).sum().item()
    
    avg_loss = total_loss / n_samples
    accuracy = 100.0 * n_correct / n_samples
    return avg_loss, accuracy

dataset_train.transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(means_train, stds_train)
])

dataset_test.transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means_test, stds_test)
])

train_loader = DataLoader(dataset_train, batch_size=batch_size, pin_memory=True, num_workers=2)
validation_loader = DataLoader(dataset_validation, batch_size=batch_size, pin_memory=True, num_workers=2)
test_loader = DataLoader(dataset_test, batch_size=batch_size, pin_memory=True, num_workers=2)

# Init
drop_prob1 = 0.15
drop_prob2 = 0.2
drop_prob_fc = 0.3
model = Model(
   # 3, 32, drop_prob1=drop_prob1, drop_prob2=drop_prob2, drop_prob_fc=drop_prob_fc
)
early_stop = EarlyStopping(patience=7, min_delta=0.01)
learning_rate = 0.001
batch_size = 64
#optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
loss_fn = nn.CrossEntropyLoss(label_smoothing=0.1)

DEVICE = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)
model = model.to(DEVICE)
print("Working on", DEVICE)

train_loader = DataLoader(
    dataset_train, batch_size=batch_size, pin_memory=True, num_workers=2
)
validation_loader = DataLoader(
    dataset_validation,
    batch_size=len(dataset_validation),
    pin_memory=True,
    num_workers=2,
)
test_loader = DataLoader(
    dataset_test, batch_size=len(dataset_test), pin_memory=True, num_workers=2
)

# Training Loop
n_epochs = 200
logging_interval = 500

def fit(model, epochs=200, logging_interval=100):
    train_loss_list = []
    val_loss_list = []
    
    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        
        for step, (data, target) in enumerate(train_loader):
            data, target = data.to(DEVICE), target.to(DEVICE)
            
            optimizer.zero_grad()
            output = model(data)
            loss = loss_fn(output, target)
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
        
        # Step scheduler AFTER each epoch
        scheduler.step()
        
        # Validate
        val_loss, val_acc = evaluate_model(model, validation_loader, loss_fn)
        avg_train_loss = epoch_loss / len(train_loader)
        
        print(f"Epoch {epoch+1}/{epochs}: "
              f"Train Loss: {avg_train_loss:.4f} | "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}% | "
              f"LR: {scheduler.get_last_lr()[0]:.6f}")
        
        train_loss_list.append(avg_train_loss)
        val_loss_list.append(val_loss)
    
    return model, train_loss_list, val_loss_list

# model, train_loss_list, train_acc_list, val_loss_list, val_acc_list = fit(
#     model, epochs=n_epochs, logging_interval=logging_interval
# )

# Final test evaluation
model, train_loss_list, val_loss_list = fit(model, epochs=n_epochs)
_, test_acc = evaluate_model(model, test_loader, loss_fn)
print(f"\nTest Accuracy: {test_acc:.2f}%")
# Out:
# Model(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): GELU(approximate='none')
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): GELU(approximate='none')
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): GELU(approximate='none')
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): GELU(approximate='none')
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): Linear(in_features=4096, out_features=512, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.5, inplace=False)
#     (5): Linear(in_features=512, out_features=10, bias=True)
#   )
# )
# Working on cuda
# Epoch 1/200: Train Loss: 2.0124 | Val Loss: 1.7304, Val Acc: 40.30% | LR: 0.099994
# Epoch 2/200: Train Loss: 1.6104 | Val Loss: 1.4633, Val Acc: 55.34% | LR: 0.099975
# Epoch 3/200: Train Loss: 1.3650 | Val Loss: 1.3418, Val Acc: 62.08% | LR: 0.099944
# Epoch 4/200: Train Loss: 1.2468 | Val Loss: 1.1887, Val Acc: 69.34% | LR: 0.099901
# Epoch 5/200: Train Loss: 1.1682 | Val Loss: 1.0960, Val Acc: 74.50% | LR: 0.099846
# Epoch 6/200: Train Loss: 1.1130 | Val Loss: 1.1442, Val Acc: 72.16% | LR: 0.099778
# Epoch 7/200: Train Loss: 1.0739 | Val Loss: 1.0420, Val Acc: 76.74% | LR: 0.099698
# Epoch 8/200: Train Loss: 1.0498 | Val Loss: 1.0495, Val Acc: 76.00% | LR: 0.099606
# Epoch 9/200: Train Loss: 1.0291 | Val Loss: 1.0951, Val Acc: 74.12% | LR: 0.099501
# Epoch 10/200: Train Loss: 1.0131 | Val Loss: 1.0465, Val Acc: 76.86% | LR: 0.099384
# Epoch 11/200: Train Loss: 1.0047 | Val Loss: 1.0020, Val Acc: 79.34% | LR: 0.099255
# Epoch 12/200: Train Loss: 0.9915 | Val Loss: 1.0156, Val Acc: 78.56% | LR: 0.099114
# Epoch 13/200: Train Loss: 0.9835 | Val Loss: 1.0374, Val Acc: 77.16% | LR: 0.098961
# Epoch 14/200: Train Loss: 0.9820 | Val Loss: 0.9463, Val Acc: 81.30% | LR: 0.098796
# Epoch 15/200: Train Loss: 0.9690 | Val Loss: 0.9558, Val Acc: 80.06% | LR: 0.098618
# Epoch 16/200: Train Loss: 0.9706 | Val Loss: 1.0048, Val Acc: 78.56% | LR: 0.098429
# Epoch 17/200: Train Loss: 0.9600 | Val Loss: 0.9559, Val Acc: 80.78% | LR: 0.098228
# Epoch 18/200: Train Loss: 0.9636 | Val Loss: 1.0051, Val Acc: 78.62% | LR: 0.098015
# Epoch 19/200: Train Loss: 0.9555 | Val Loss: 1.0050, Val Acc: 78.38% | LR: 0.097790
# Epoch 20/200: Train Loss: 0.9500 | Val Loss: 0.9950, Val Acc: 79.48% | LR: 0.097553
# Epoch 21/200: Train Loss: 0.9501 | Val Loss: 0.9402, Val Acc: 81.74% | LR: 0.097304
# Epoch 22/200: Train Loss: 0.9452 | Val Loss: 0.9545, Val Acc: 80.70% | LR: 0.097044
# Epoch 23/200: Train Loss: 0.9438 | Val Loss: 1.0132, Val Acc: 77.78% | LR: 0.096772
# Epoch 24/200: Train Loss: 0.9396 | Val Loss: 1.0490, Val Acc: 76.54% | LR: 0.096489
# Epoch 25/200: Train Loss: 0.9340 | Val Loss: 0.9849, Val Acc: 79.70% | LR: 0.096194
# Epoch 26/200: Train Loss: 0.9324 | Val Loss: 0.9940, Val Acc: 78.66% | LR: 0.095888
# Epoch 27/200: Train Loss: 0.9274 | Val Loss: 0.9485, Val Acc: 81.84% | LR: 0.095570
# Epoch 28/200: Train Loss: 0.9336 | Val Loss: 0.9103, Val Acc: 83.00% | LR: 0.095241
# Epoch 29/200: Train Loss: 0.9299 | Val Loss: 0.9491, Val Acc: 80.76% | LR: 0.094901
# Epoch 30/200: Train Loss: 0.9253 | Val Loss: 1.0060, Val Acc: 78.42% | LR: 0.094550
# Epoch 31/200: Train Loss: 0.9236 | Val Loss: 0.9826, Val Acc: 79.86% | LR: 0.094188
# Epoch 32/200: Train Loss: 0.9223 | Val Loss: 1.0064, Val Acc: 78.62% | LR: 0.093815
# Epoch 33/200: Train Loss: 0.9227 | Val Loss: 1.0103, Val Acc: 78.10% | LR: 0.093432
# Epoch 34/200: Train Loss: 0.9138 | Val Loss: 0.9545, Val Acc: 81.30% | LR: 0.093037
# Epoch 35/200: Train Loss: 0.9196 | Val Loss: 0.9537, Val Acc: 80.66% | LR: 0.092632
# Epoch 36/200: Train Loss: 0.9123 | Val Loss: 0.9818, Val Acc: 79.64% | LR: 0.092216
# Epoch 37/200: Train Loss: 0.9110 | Val Loss: 0.9485, Val Acc: 81.36% | LR: 0.091790
# Epoch 38/200: Train Loss: 0.9109 | Val Loss: 0.9446, Val Acc: 80.64% | LR: 0.091354
# Epoch 39/200: Train Loss: 0.9120 | Val Loss: 0.9180, Val Acc: 82.16% | LR: 0.090907
# Epoch 40/200: Train Loss: 0.9069 | Val Loss: 0.9709, Val Acc: 80.46% | LR: 0.090451
# Epoch 41/200: Train Loss: 0.9111 | Val Loss: 0.9690, Val Acc: 79.28% | LR: 0.089984
# Epoch 42/200: Train Loss: 0.9033 | Val Loss: 0.8882, Val Acc: 84.06% | LR: 0.089508
# Epoch 43/200: Train Loss: 0.9053 | Val Loss: 0.9602, Val Acc: 80.04% | LR: 0.089022
# Epoch 44/200: Train Loss: 0.9065 | Val Loss: 0.9220, Val Acc: 81.78% | LR: 0.088526
# Epoch 45/200: Train Loss: 0.9017 | Val Loss: 0.9498, Val Acc: 81.28% | LR: 0.088020
# Epoch 46/200: Train Loss: 0.9011 | Val Loss: 0.9102, Val Acc: 82.68% | LR: 0.087506
# Epoch 47/200: Train Loss: 0.9029 | Val Loss: 0.9300, Val Acc: 82.06% | LR: 0.086982
# Epoch 48/200: Train Loss: 0.8965 | Val Loss: 0.9214, Val Acc: 82.06% | LR: 0.086448
# Epoch 49/200: Train Loss: 0.8960 | Val Loss: 0.9625, Val Acc: 80.82% | LR: 0.085906
# Epoch 50/200: Train Loss: 0.8913 | Val Loss: 0.9040, Val Acc: 83.48% | LR: 0.085355
# Epoch 51/200: Train Loss: 0.8907 | Val Loss: 0.9299, Val Acc: 81.40% | LR: 0.084796
# Epoch 52/200: Train Loss: 0.8882 | Val Loss: 0.8844, Val Acc: 83.72% | LR: 0.084227
# Epoch 53/200: Train Loss: 0.8861 | Val Loss: 0.9183, Val Acc: 82.88% | LR: 0.083651
# Epoch 54/200: Train Loss: 0.8909 | Val Loss: 0.9137, Val Acc: 82.16% | LR: 0.083066
# Epoch 55/200: Train Loss: 0.8842 | Val Loss: 0.8920, Val Acc: 83.80% | LR: 0.082472
# Epoch 56/200: Train Loss: 0.8861 | Val Loss: 0.9251, Val Acc: 82.22% | LR: 0.081871
# Epoch 57/200: Train Loss: 0.8845 | Val Loss: 0.9924, Val Acc: 79.32% | LR: 0.081262
# Epoch 58/200: Train Loss: 0.8816 | Val Loss: 0.9261, Val Acc: 82.08% | LR: 0.080645
# Epoch 59/200: Train Loss: 0.8809 | Val Loss: 0.8992, Val Acc: 83.04% | LR: 0.080021
# Epoch 60/200: Train Loss: 0.8790 | Val Loss: 0.9334, Val Acc: 82.02% | LR: 0.079389
# Epoch 61/200: Train Loss: 0.8756 | Val Loss: 0.8607, Val Acc: 84.78% | LR: 0.078750
# Epoch 62/200: Train Loss: 0.8753 | Val Loss: 0.9295, Val Acc: 81.94% | LR: 0.078104
# Epoch 63/200: Train Loss: 0.8717 | Val Loss: 0.8735, Val Acc: 84.24% | LR: 0.077451
# Epoch 64/200: Train Loss: 0.8755 | Val Loss: 0.9042, Val Acc: 83.02% | LR: 0.076791
# Epoch 65/200: Train Loss: 0.8671 | Val Loss: 0.8558, Val Acc: 85.20% | LR: 0.076125
# Epoch 66/200: Train Loss: 0.8656 | Val Loss: 0.8412, Val Acc: 86.00% | LR: 0.075452
# Epoch 67/200: Train Loss: 0.8657 | Val Loss: 0.9370, Val Acc: 81.06% | LR: 0.074773
# Epoch 68/200: Train Loss: 0.8648 | Val Loss: 0.8712, Val Acc: 84.76% | LR: 0.074088
# Epoch 69/200: Train Loss: 0.8605 | Val Loss: 0.9301, Val Acc: 82.04% | LR: 0.073396
# Epoch 70/200: Train Loss: 0.8592 | Val Loss: 0.8730, Val Acc: 84.20% | LR: 0.072700
# Epoch 71/200: Train Loss: 0.8575 | Val Loss: 0.9068, Val Acc: 83.24% | LR: 0.071997
# Epoch 72/200: Train Loss: 0.8556 | Val Loss: 0.8792, Val Acc: 84.20% | LR: 0.071289
# Epoch 73/200: Train Loss: 0.8557 | Val Loss: 0.8912, Val Acc: 83.66% | LR: 0.070576
# Epoch 74/200: Train Loss: 0.8497 | Val Loss: 0.9029, Val Acc: 83.24% | LR: 0.069857
# Epoch 75/200: Train Loss: 0.8504 | Val Loss: 0.9546, Val Acc: 81.18% | LR: 0.069134
# Epoch 76/200: Train Loss: 0.8511 | Val Loss: 0.8709, Val Acc: 84.50% | LR: 0.068406
# Epoch 77/200: Train Loss: 0.8478 | Val Loss: 0.8698, Val Acc: 83.84% | LR: 0.067674
# Epoch 78/200: Train Loss: 0.8441 | Val Loss: 0.9131, Val Acc: 82.84% | LR: 0.066937
# Epoch 79/200: Train Loss: 0.8429 | Val Loss: 0.8734, Val Acc: 84.26% | LR: 0.066196
# Epoch 80/200: Train Loss: 0.8391 | Val Loss: 0.8654, Val Acc: 84.72% | LR: 0.065451
# Epoch 81/200: Train Loss: 0.8365 | Val Loss: 0.8635, Val Acc: 84.84% | LR: 0.064702
# Epoch 82/200: Train Loss: 0.8332 | Val Loss: 0.8532, Val Acc: 85.14% | LR: 0.063950
# Epoch 83/200: Train Loss: 0.8308 | Val Loss: 0.8864, Val Acc: 83.92% | LR: 0.063194
# Epoch 84/200: Train Loss: 0.8319 | Val Loss: 0.8385, Val Acc: 85.62% | LR: 0.062434
# Epoch 85/200: Train Loss: 0.8261 | Val Loss: 0.8911, Val Acc: 83.10% | LR: 0.061672
# Epoch 86/200: Train Loss: 0.8220 | Val Loss: 0.8899, Val Acc: 83.38% | LR: 0.060907
# Epoch 87/200: Train Loss: 0.8235 | Val Loss: 0.8543, Val Acc: 84.84% | LR: 0.060139
# Epoch 88/200: Train Loss: 0.8156 | Val Loss: 0.8559, Val Acc: 85.44% | LR: 0.059369
# Epoch 89/200: Train Loss: 0.8200 | Val Loss: 0.8466, Val Acc: 85.68% | LR: 0.058596
# Epoch 90/200: Train Loss: 0.8138 | Val Loss: 0.9088, Val Acc: 82.54% | LR: 0.057822
# Epoch 91/200: Train Loss: 0.8160 | Val Loss: 0.9309, Val Acc: 81.88% | LR: 0.057045
# Epoch 92/200: Train Loss: 0.8131 | Val Loss: 0.8512, Val Acc: 85.56% | LR: 0.056267
# Epoch 93/200: Train Loss: 0.8104 | Val Loss: 0.9439, Val Acc: 81.04% | LR: 0.055487
# Epoch 94/200: Train Loss: 0.8097 | Val Loss: 0.8836, Val Acc: 84.00% | LR: 0.054705
# Epoch 95/200: Train Loss: 0.8054 | Val Loss: 0.8527, Val Acc: 85.22% | LR: 0.053923
# Epoch 96/200: Train Loss: 0.8091 | Val Loss: 0.8771, Val Acc: 83.96% | LR: 0.053140
# Epoch 97/200: Train Loss: 0.7981 | Val Loss: 0.8251, Val Acc: 86.06% | LR: 0.052355
# Epoch 98/200: Train Loss: 0.8015 | Val Loss: 0.8525, Val Acc: 85.18% | LR: 0.051571
# Epoch 99/200: Train Loss: 0.7977 | Val Loss: 0.8270, Val Acc: 86.46% | LR: 0.050785
# Epoch 100/200: Train Loss: 0.7931 | Val Loss: 0.8789, Val Acc: 84.24% | LR: 0.050000
# Epoch 101/200: Train Loss: 0.7934 | Val Loss: 0.8809, Val Acc: 83.82% | LR: 0.049215
# Epoch 102/200: Train Loss: 0.7900 | Val Loss: 0.8433, Val Acc: 85.80% | LR: 0.048429
# Epoch 103/200: Train Loss: 0.7886 | Val Loss: 0.8707, Val Acc: 84.80% | LR: 0.047645
# Epoch 104/200: Train Loss: 0.7815 | Val Loss: 0.8027, Val Acc: 87.02% | LR: 0.046860
# Epoch 105/200: Train Loss: 0.7822 | Val Loss: 0.8193, Val Acc: 86.64% | LR: 0.046077
# Epoch 106/200: Train Loss: 0.7744 | Val Loss: 0.8396, Val Acc: 85.86% | LR: 0.045295
# Epoch 107/200: Train Loss: 0.7735 | Val Loss: 0.8116, Val Acc: 86.66% | LR: 0.044513
# Epoch 108/200: Train Loss: 0.7692 | Val Loss: 0.8382, Val Acc: 85.94% | LR: 0.043733
# Epoch 109/200: Train Loss: 0.7685 | Val Loss: 0.8676, Val Acc: 84.82% | LR: 0.042955
# Epoch 110/200: Train Loss: 0.7714 | Val Loss: 0.8957, Val Acc: 83.08% | LR: 0.042178
# Epoch 111/200: Train Loss: 0.7625 | Val Loss: 0.8078, Val Acc: 86.88% | LR: 0.041404
# Epoch 112/200: Train Loss: 0.7598 | Val Loss: 0.8268, Val Acc: 86.30% | LR: 0.040631
# Epoch 113/200: Train Loss: 0.7602 | Val Loss: 0.8060, Val Acc: 86.96% | LR: 0.039861
# Epoch 114/200: Train Loss: 0.7563 | Val Loss: 0.8399, Val Acc: 86.28% | LR: 0.039093
# Epoch 115/200: Train Loss: 0.7495 | Val Loss: 0.8085, Val Acc: 87.02% | LR: 0.038328
# Epoch 116/200: Train Loss: 0.7516 | Val Loss: 0.8272, Val Acc: 86.46% | LR: 0.037566
# Epoch 117/200: Train Loss: 0.7478 | Val Loss: 0.8186, Val Acc: 86.96% | LR: 0.036806
# Epoch 118/200: Train Loss: 0.7455 | Val Loss: 0.8243, Val Acc: 87.28% | LR: 0.036050
# Epoch 119/200: Train Loss: 0.7377 | Val Loss: 0.8295, Val Acc: 86.30% | LR: 0.035298
# Epoch 120/200: Train Loss: 0.7355 | Val Loss: 0.8135, Val Acc: 87.52% | LR: 0.034549
# Epoch 121/200: Train Loss: 0.7340 | Val Loss: 0.8030, Val Acc: 87.50% | LR: 0.033804
# Epoch 122/200: Train Loss: 0.7297 | Val Loss: 0.7985, Val Acc: 87.98% | LR: 0.033063
# Epoch 123/200: Train Loss: 0.7271 | Val Loss: 0.7798, Val Acc: 88.04% | LR: 0.032326
# Epoch 124/200: Train Loss: 0.7258 | Val Loss: 0.8184, Val Acc: 86.60% | LR: 0.031594
# Epoch 125/200: Train Loss: 0.7246 | Val Loss: 0.8040, Val Acc: 87.70% | LR: 0.030866
# Epoch 126/200: Train Loss: 0.7189 | Val Loss: 0.7832, Val Acc: 87.94% | LR: 0.030143
# Epoch 127/200: Train Loss: 0.7133 | Val Loss: 0.8152, Val Acc: 86.62% | LR: 0.029424
# Epoch 128/200: Train Loss: 0.7133 | Val Loss: 0.7981, Val Acc: 87.76% | LR: 0.028711
# Epoch 129/200: Train Loss: 0.7091 | Val Loss: 0.7753, Val Acc: 88.82% | LR: 0.028003
# Epoch 130/200: Train Loss: 0.7094 | Val Loss: 0.7683, Val Acc: 88.86% | LR: 0.027300
# Epoch 131/200: Train Loss: 0.7037 | Val Loss: 0.7842, Val Acc: 88.32% | LR: 0.026604
# Epoch 132/200: Train Loss: 0.7009 | Val Loss: 0.7886, Val Acc: 87.96% | LR: 0.025912
# Epoch 133/200: Train Loss: 0.6965 | Val Loss: 0.7988, Val Acc: 87.36% | LR: 0.025227
# Epoch 134/200: Train Loss: 0.6925 | Val Loss: 0.7985, Val Acc: 87.72% | LR: 0.024548
# Epoch 135/200: Train Loss: 0.6876 | Val Loss: 0.7591, Val Acc: 89.60% | LR: 0.023875
# Epoch 136/200: Train Loss: 0.6840 | Val Loss: 0.7810, Val Acc: 88.68% | LR: 0.023209
# Epoch 137/200: Train Loss: 0.6839 | Val Loss: 0.7760, Val Acc: 88.44% | LR: 0.022549
# Epoch 138/200: Train Loss: 0.6758 | Val Loss: 0.7679, Val Acc: 89.08% | LR: 0.021896
# Epoch 139/200: Train Loss: 0.6794 | Val Loss: 0.7787, Val Acc: 88.58% | LR: 0.021250
# Epoch 140/200: Train Loss: 0.6708 | Val Loss: 0.7816, Val Acc: 87.92% | LR: 0.020611
# Epoch 141/200: Train Loss: 0.6678 | Val Loss: 0.7591, Val Acc: 89.20% | LR: 0.019979
# Epoch 142/200: Train Loss: 0.6606 | Val Loss: 0.7586, Val Acc: 89.20% | LR: 0.019355
# Epoch 143/200: Train Loss: 0.6603 | Val Loss: 0.7532, Val Acc: 89.52% | LR: 0.018738
# Epoch 144/200: Train Loss: 0.6547 | Val Loss: 0.7383, Val Acc: 90.42% | LR: 0.018129
# Epoch 145/200: Train Loss: 0.6519 | Val Loss: 0.7888, Val Acc: 88.24% | LR: 0.017528
# Epoch 146/200: Train Loss: 0.6494 | Val Loss: 0.7547, Val Acc: 89.44% | LR: 0.016934
# Epoch 147/200: Train Loss: 0.6456 | Val Loss: 0.7381, Val Acc: 90.44% | LR: 0.016349
# Epoch 148/200: Train Loss: 0.6404 | Val Loss: 0.7699, Val Acc: 88.96% | LR: 0.015773
# Epoch 149/200: Train Loss: 0.6376 | Val Loss: 0.7352, Val Acc: 90.58% | LR: 0.015204
# Epoch 150/200: Train Loss: 0.6355 | Val Loss: 0.7575, Val Acc: 89.52% | LR: 0.014645
# Epoch 151/200: Train Loss: 0.6289 | Val Loss: 0.7716, Val Acc: 88.38% | LR: 0.014094
# Epoch 152/200: Train Loss: 0.6281 | Val Loss: 0.7548, Val Acc: 89.68% | LR: 0.013552
# Epoch 153/200: Train Loss: 0.6250 | Val Loss: 0.7627, Val Acc: 89.38% | LR: 0.013018
# Epoch 154/200: Train Loss: 0.6208 | Val Loss: 0.7666, Val Acc: 89.02% | LR: 0.012494
# Epoch 155/200: Train Loss: 0.6184 | Val Loss: 0.7375, Val Acc: 90.86% | LR: 0.011980
# Epoch 156/200: Train Loss: 0.6105 | Val Loss: 0.7182, Val Acc: 90.98% | LR: 0.011474
# Epoch 157/200: Train Loss: 0.6051 | Val Loss: 0.7226, Val Acc: 91.12% | LR: 0.010978
# Epoch 158/200: Train Loss: 0.6020 | Val Loss: 0.7339, Val Acc: 90.40% | LR: 0.010492
# Epoch 159/200: Train Loss: 0.5970 | Val Loss: 0.7450, Val Acc: 90.02% | LR: 0.010016
# Epoch 160/200: Train Loss: 0.5965 | Val Loss: 0.7312, Val Acc: 90.44% | LR: 0.009549
# Epoch 161/200: Train Loss: 0.5939 | Val Loss: 0.7189, Val Acc: 91.20% | LR: 0.009093
# Epoch 162/200: Train Loss: 0.5880 | Val Loss: 0.7430, Val Acc: 90.06% | LR: 0.008646
# Epoch 163/200: Train Loss: 0.5864 | Val Loss: 0.7141, Val Acc: 91.72% | LR: 0.008210
# Epoch 164/200: Train Loss: 0.5803 | Val Loss: 0.7254, Val Acc: 90.74% | LR: 0.007784
# Epoch 165/200: Train Loss: 0.5780 | Val Loss: 0.7222, Val Acc: 91.12% | LR: 0.007368
# Epoch 166/200: Train Loss: 0.5722 | Val Loss: 0.7055, Val Acc: 91.64% | LR: 0.006963
# Epoch 167/200: Train Loss: 0.5691 | Val Loss: 0.7197, Val Acc: 91.24% | LR: 0.006568
# Epoch 168/200: Train Loss: 0.5654 | Val Loss: 0.7092, Val Acc: 91.56% | LR: 0.006185
# Epoch 169/200: Train Loss: 0.5629 | Val Loss: 0.7130, Val Acc: 91.54% | LR: 0.005812
# Epoch 170/200: Train Loss: 0.5584 | Val Loss: 0.7018, Val Acc: 91.88% | LR: 0.005450
# Epoch 171/200: Train Loss: 0.5555 | Val Loss: 0.7128, Val Acc: 91.52% | LR: 0.005099
# Epoch 172/200: Train Loss: 0.5537 | Val Loss: 0.6975, Val Acc: 92.08% | LR: 0.004759
# Epoch 173/200: Train Loss: 0.5488 | Val Loss: 0.6943, Val Acc: 92.40% | LR: 0.004430
# Epoch 174/200: Train Loss: 0.5474 | Val Loss: 0.6980, Val Acc: 92.16% | LR: 0.004112
# Epoch 175/200: Train Loss: 0.5436 | Val Loss: 0.6954, Val Acc: 92.14% | LR: 0.003806
# Epoch 176/200: Train Loss: 0.5421 | Val Loss: 0.6899, Val Acc: 92.48% | LR: 0.003511
# Epoch 177/200: Train Loss: 0.5377 | Val Loss: 0.6953, Val Acc: 92.30% | LR: 0.003228
# Epoch 178/200: Train Loss: 0.5372 | Val Loss: 0.6904, Val Acc: 92.44% | LR: 0.002956
# Epoch 179/200: Train Loss: 0.5346 | Val Loss: 0.6913, Val Acc: 92.08% | LR: 0.002696
# Epoch 180/200: Train Loss: 0.5326 | Val Loss: 0.6941, Val Acc: 92.28% | LR: 0.002447
# Epoch 181/200: Train Loss: 0.5318 | Val Loss: 0.6895, Val Acc: 92.40% | LR: 0.002210
# Epoch 182/200: Train Loss: 0.5296 | Val Loss: 0.6881, Val Acc: 92.50% | LR: 0.001985
# Epoch 183/200: Train Loss: 0.5280 | Val Loss: 0.6856, Val Acc: 92.52% | LR: 0.001772
# Epoch 184/200: Train Loss: 0.5273 | Val Loss: 0.6887, Val Acc: 92.58% | LR: 0.001571
# Epoch 185/200: Train Loss: 0.5267 | Val Loss: 0.6884, Val Acc: 92.48% | LR: 0.001382
# Epoch 186/200: Train Loss: 0.5252 | Val Loss: 0.6860, Val Acc: 92.50% | LR: 0.001204
# Epoch 187/200: Train Loss: 0.5251 | Val Loss: 0.6824, Val Acc: 92.84% | LR: 0.001039
# Epoch 188/200: Train Loss: 0.5244 | Val Loss: 0.6849, Val Acc: 92.62% | LR: 0.000886
# Epoch 189/200: Train Loss: 0.5241 | Val Loss: 0.6843, Val Acc: 92.52% | LR: 0.000745
# Epoch 190/200: Train Loss: 0.5234 | Val Loss: 0.6804, Val Acc: 92.84% | LR: 0.000616
# Epoch 191/200: Train Loss: 0.5232 | Val Loss: 0.6822, Val Acc: 92.72% | LR: 0.000499
# Epoch 192/200: Train Loss: 0.5223 | Val Loss: 0.6813, Val Acc: 92.84% | LR: 0.000394
# Epoch 193/200: Train Loss: 0.5223 | Val Loss: 0.6806, Val Acc: 92.84% | LR: 0.000302
# Epoch 194/200: Train Loss: 0.5222 | Val Loss: 0.6808, Val Acc: 92.88% | LR: 0.000222
# Epoch 195/200: Train Loss: 0.5215 | Val Loss: 0.6798, Val Acc: 92.92% | LR: 0.000154
# Epoch 196/200: Train Loss: 0.5214 | Val Loss: 0.6787, Val Acc: 92.98% | LR: 0.000099
# Epoch 197/200: Train Loss: 0.5216 | Val Loss: 0.6787, Val Acc: 92.98% | LR: 0.000056
# Epoch 198/200: Train Loss: 0.5214 | Val Loss: 0.6790, Val Acc: 92.96% | LR: 0.000025
# Epoch 199/200: Train Loss: 0.5211 | Val Loss: 0.6791, Val Acc: 92.96% | LR: 0.000006
# Epoch 200/200: Train Loss: 0.5214 | Val Loss: 0.6795, Val Acc: 92.94% | LR: 0.000000
#
# Test Accuracy: 93.00%

# %%
plt.figure(figsize=(10, 7))
steps = [x * logging_interval for x in range(len(train_loss_list))]
plt.plot(steps, train_loss_list, label='Training Loss')
plt.plot(steps, val_loss_list, label='Validation Loss')
plt.title("CIFER10")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task 9 (10 pts)
#
# Until now, we asked you to keep the seed fixed.
# Train **the model you defined at Task 5** five times with 5 different seeds (already specified below, **don't change them**), each for the same number of epochs epochs.
# Don't change other hyperparameters. Observe the accuracy of the test set in each case. What can you say?

# %%
test_accs = []
for seed in range(5):
    torch.manual_seed(seed)
    print(f"Testing seed {seed}", flush = True)
    
    # init
    model = Model_OG(3, 32)
    early_stop = EarlyStopping(patience=10, min_delta=0.01)
    learning_rate = 0.03
    batch_size = 32
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    loss_fn = nn.CrossEntropyLoss()
    print(model.dimensions_final)

    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'mps' 
        if torch.backends.mps.is_available() else 'cpu')
    model = model.to(DEVICE)
    print("Working on", DEVICE)
    
    # Training loop
    n_epochs = 5
    logging_interval = len(train_loader)
    model,_,_,_,_ = fit(model, logging_interval=logging_interval)

    # Final test evaluation
    _, test_acc = evaluate_model(model, test_loader, loss_fn)
    test_accs.append(test_acc)
    print(f"\nTest Accuracy: {test_acc:.2f}%")
# Out:
# Testing seed 0
# (20, 4, 4)
# Working on cuda
# Epoch 1/200: Train Loss: 2.0208 | Val Loss: 1.7423, Val Acc: 35.66% | LR: 0.000006
# Epoch 2/200: Train Loss: 1.6820 | Val Loss: 1.5379, Val Acc: 44.08% | LR: 0.000025
# Epoch 3/200: Train Loss: 1.5330 | Val Loss: 1.6583, Val Acc: 41.70% | LR: 0.000056
# Epoch 4/200: Train Loss: 1.4306 | Val Loss: 1.4469, Val Acc: 48.78% | LR: 0.000099
# Epoch 5/200: Train Loss: 1.3352 | Val Loss: 1.3240, Val Acc: 53.44% | LR: 0.000154
# Epoch 6/200: Train Loss: 1.2543 | Val Loss: 1.2602, Val Acc: 55.16% | LR: 0.000222
# Epoch 7/200: Train Loss: 1.1829 | Val Loss: 1.3442, Val Acc: 52.90% | LR: 0.000302
# Epoch 8/200: Train Loss: 1.1296 | Val Loss: 1.3586, Val Acc: 54.50% | LR: 0.000394
# Epoch 9/200: Train Loss: 1.0759 | Val Loss: 1.3088, Val Acc: 55.26% | LR: 0.000499
# Epoch 10/200: Train Loss: 1.0317 | Val Loss: 1.0272, Val Acc: 63.78% | LR: 0.000616
# Epoch 11/200: Train Loss: 0.9931 | Val Loss: 1.0923, Val Acc: 62.80% | LR: 0.000745
# Epoch 12/200: Train Loss: 0.9696 | Val Loss: 0.9702, Val Acc: 66.92% | LR: 0.000886
# Epoch 13/200: Train Loss: 0.9422 | Val Loss: 1.1518, Val Acc: 60.08% | LR: 0.001039
# Epoch 14/200: Train Loss: 0.9185 | Val Loss: 1.2367, Val Acc: 59.06% | LR: 0.001204
# Epoch 15/200: Train Loss: 0.9034 | Val Loss: 0.8993, Val Acc: 69.16% | LR: 0.001382
# Epoch 16/200: Train Loss: 0.8828 | Val Loss: 0.9571, Val Acc: 66.66% | LR: 0.001571
# Epoch 17/200: Train Loss: 0.8677 | Val Loss: 0.9056, Val Acc: 67.66% | LR: 0.001772
# Epoch 18/200: Train Loss: 0.8548 | Val Loss: 1.0375, Val Acc: 64.72% | LR: 0.001985
# Epoch 19/200: Train Loss: 0.8347 | Val Loss: 1.1084, Val Acc: 63.06% | LR: 0.002210
# Epoch 20/200: Train Loss: 0.8278 | Val Loss: 0.9444, Val Acc: 67.26% | LR: 0.002447
# Epoch 21/200: Train Loss: 0.8140 | Val Loss: 0.9271, Val Acc: 67.72% | LR: 0.002696
# Epoch 22/200: Train Loss: 0.8044 | Val Loss: 0.9307, Val Acc: 67.84% | LR: 0.002956
# Epoch 23/200: Train Loss: 0.7920 | Val Loss: 0.8879, Val Acc: 69.16% | LR: 0.003228
# Epoch 24/200: Train Loss: 0.7839 | Val Loss: 0.8037, Val Acc: 72.08% | LR: 0.003511
# Epoch 25/200: Train Loss: 0.7774 | Val Loss: 0.9115, Val Acc: 69.04% | LR: 0.003806
# Epoch 26/200: Train Loss: 0.7694 | Val Loss: 0.8754, Val Acc: 69.64% | LR: 0.004112
# Epoch 27/200: Train Loss: 0.7610 | Val Loss: 0.7937, Val Acc: 73.02% | LR: 0.004430
# Epoch 28/200: Train Loss: 0.7550 | Val Loss: 0.9725, Val Acc: 67.44% | LR: 0.004759
# Epoch 29/200: Train Loss: 0.7457 | Val Loss: 0.8977, Val Acc: 69.18% | LR: 0.005099
# Epoch 30/200: Train Loss: 0.7439 | Val Loss: 0.8835, Val Acc: 69.64% | LR: 0.005450
# Epoch 31/200: Train Loss: 0.7359 | Val Loss: 0.7740, Val Acc: 72.98% | LR: 0.005812
# Epoch 32/200: Train Loss: 0.7278 | Val Loss: 0.8519, Val Acc: 71.14% | LR: 0.006185
# Epoch 33/200: Train Loss: 0.7286 | Val Loss: 0.8911, Val Acc: 69.76% | LR: 0.006568
# Epoch 34/200: Train Loss: 0.7219 | Val Loss: 1.0917, Val Acc: 65.24% | LR: 0.006963
# Epoch 35/200: Train Loss: 0.7157 | Val Loss: 0.7431, Val Acc: 73.82% | LR: 0.007368
# Epoch 36/200: Train Loss: 0.7052 | Val Loss: 0.8004, Val Acc: 72.18% | LR: 0.007784
# Epoch 37/200: Train Loss: 0.7033 | Val Loss: 0.7737, Val Acc: 73.56% | LR: 0.008210
# Epoch 38/200: Train Loss: 0.6979 | Val Loss: 0.8145, Val Acc: 72.96% | LR: 0.008646
# Epoch 39/200: Train Loss: 0.6962 | Val Loss: 0.8088, Val Acc: 71.98% | LR: 0.009093
# Epoch 40/200: Train Loss: 0.6904 | Val Loss: 0.8006, Val Acc: 72.60% | LR: 0.009549
# Epoch 41/200: Train Loss: 0.6882 | Val Loss: 1.0404, Val Acc: 66.18% | LR: 0.010016
# Epoch 42/200: Train Loss: 0.6858 | Val Loss: 0.7005, Val Acc: 75.78% | LR: 0.010492
# Epoch 43/200: Train Loss: 0.6824 | Val Loss: 0.7277, Val Acc: 75.30% | LR: 0.010978
# Epoch 44/200: Train Loss: 0.6754 | Val Loss: 0.7674, Val Acc: 74.00% | LR: 0.011474
# Epoch 45/200: Train Loss: 0.6729 | Val Loss: 0.7136, Val Acc: 75.34% | LR: 0.011980
# Epoch 46/200: Train Loss: 0.6678 | Val Loss: 0.7981, Val Acc: 73.24% | LR: 0.012494
# Epoch 47/200: Train Loss: 0.6628 | Val Loss: 0.7403, Val Acc: 75.46% | LR: 0.013018
# Epoch 48/200: Train Loss: 0.6651 | Val Loss: 0.7451, Val Acc: 74.94% | LR: 0.013552
# Epoch 49/200: Train Loss: 0.6584 | Val Loss: 0.8085, Val Acc: 73.04% | LR: 0.014094
# Epoch 50/200: Train Loss: 0.6573 | Val Loss: 0.7808, Val Acc: 74.36% | LR: 0.014645
# Epoch 51/200: Train Loss: 0.6576 | Val Loss: 0.7449, Val Acc: 74.22% | LR: 0.015204
# Epoch 52/200: Train Loss: 0.6489 | Val Loss: 0.7756, Val Acc: 73.78% | LR: 0.015773
# Epoch 53/200: Train Loss: 0.6492 | Val Loss: 0.7192, Val Acc: 75.66% | LR: 0.016349
# Epoch 54/200: Train Loss: 0.6482 | Val Loss: 0.7153, Val Acc: 75.98% | LR: 0.016934
# Epoch 55/200: Train Loss: 0.6402 | Val Loss: 0.7171, Val Acc: 75.72% | LR: 0.017528
# Epoch 56/200: Train Loss: 0.6412 | Val Loss: 0.7378, Val Acc: 74.72% | LR: 0.018129
# Epoch 57/200: Train Loss: 0.6420 | Val Loss: 0.8510, Val Acc: 71.90% | LR: 0.018738
# Epoch 58/200: Train Loss: 0.6343 | Val Loss: 0.7694, Val Acc: 73.92% | LR: 0.019355
# Epoch 59/200: Train Loss: 0.6307 | Val Loss: 0.6859, Val Acc: 76.82% | LR: 0.019979
# Epoch 60/200: Train Loss: 0.6282 | Val Loss: 0.7098, Val Acc: 76.06% | LR: 0.020611
# Epoch 61/200: Train Loss: 0.6247 | Val Loss: 0.7261, Val Acc: 75.20% | LR: 0.021250
# Epoch 62/200: Train Loss: 0.6289 | Val Loss: 1.0568, Val Acc: 66.80% | LR: 0.021896
# Epoch 63/200: Train Loss: 0.6310 | Val Loss: 1.0742, Val Acc: 65.58% | LR: 0.022549
# Epoch 64/200: Train Loss: 0.6208 | Val Loss: 0.7675, Val Acc: 74.26% | LR: 0.023209
# Epoch 65/200: Train Loss: 0.6290 | Val Loss: 1.1808, Val Acc: 65.30% | LR: 0.023875
# Epoch 66/200: Train Loss: 0.6186 | Val Loss: 0.7329, Val Acc: 75.60% | LR: 0.024548
# Epoch 67/200: Train Loss: 0.6213 | Val Loss: 0.7667, Val Acc: 74.24% | LR: 0.025227
# Epoch 68/200: Train Loss: 0.6187 | Val Loss: 0.6972, Val Acc: 76.58% | LR: 0.025912
# Epoch 69/200: Train Loss: 0.6141 | Val Loss: 0.8282, Val Acc: 72.44% | LR: 0.026604
# Epoch 70/200: Train Loss: 0.6100 | Val Loss: 0.7035, Val Acc: 76.16% | LR: 0.027300
# Epoch 71/200: Train Loss: 0.6089 | Val Loss: 0.8341, Val Acc: 72.38% | LR: 0.028003
# Epoch 72/200: Train Loss: 0.6079 | Val Loss: 0.8100, Val Acc: 72.76% | LR: 0.028711
# Epoch 73/200: Train Loss: 0.6066 | Val Loss: 0.6764, Val Acc: 76.76% | LR: 0.029424
# Epoch 74/200: Train Loss: 0.6061 | Val Loss: 0.7098, Val Acc: 76.12% | LR: 0.030143
# Epoch 75/200: Train Loss: 0.6046 | Val Loss: 0.6792, Val Acc: 76.70% | LR: 0.030866
# Epoch 76/200: Train Loss: 0.6019 | Val Loss: 0.8062, Val Acc: 72.56% | LR: 0.031594
# Epoch 77/200: Train Loss: 0.6014 | Val Loss: 0.6333, Val Acc: 78.94% | LR: 0.032326
# Epoch 78/200: Train Loss: 0.6024 | Val Loss: 0.6780, Val Acc: 76.68% | LR: 0.033063
# Epoch 79/200: Train Loss: 0.5997 | Val Loss: 0.6963, Val Acc: 76.30% | LR: 0.033804
# Epoch 80/200: Train Loss: 0.5991 | Val Loss: 0.6944, Val Acc: 76.98% | LR: 0.034549
# Epoch 81/200: Train Loss: 0.5963 | Val Loss: 0.7468, Val Acc: 75.18% | LR: 0.035298
# Epoch 82/200: Train Loss: 0.5930 | Val Loss: 0.6894, Val Acc: 76.86% | LR: 0.036050
# Epoch 83/200: Train Loss: 0.5925 | Val Loss: 0.7759, Val Acc: 74.20% | LR: 0.036806
# Epoch 84/200: Train Loss: 0.5922 | Val Loss: 0.7524, Val Acc: 74.96% | LR: 0.037566
# Epoch 85/200: Train Loss: 0.5864 | Val Loss: 0.6923, Val Acc: 76.88% | LR: 0.038328
# Epoch 86/200: Train Loss: 0.5921 | Val Loss: 0.7238, Val Acc: 75.90% | LR: 0.039093
# Epoch 87/200: Train Loss: 0.5887 | Val Loss: 0.7225, Val Acc: 75.82% | LR: 0.039861
# Epoch 88/200: Train Loss: 0.5860 | Val Loss: 0.7854, Val Acc: 73.98% | LR: 0.040631
# Epoch 89/200: Train Loss: 0.5865 | Val Loss: 0.7236, Val Acc: 75.50% | LR: 0.041404
# Epoch 90/200: Train Loss: 0.5875 | Val Loss: 0.7528, Val Acc: 75.86% | LR: 0.042178
# Epoch 91/200: Train Loss: 0.5814 | Val Loss: 0.7835, Val Acc: 74.26% | LR: 0.042955
# Epoch 92/200: Train Loss: 0.5786 | Val Loss: 0.7385, Val Acc: 75.38% | LR: 0.043733
# Epoch 93/200: Train Loss: 0.5833 | Val Loss: 0.7070, Val Acc: 76.42% | LR: 0.044513
# Epoch 94/200: Train Loss: 0.5798 | Val Loss: 0.6802, Val Acc: 77.10% | LR: 0.045295
# Epoch 95/200: Train Loss: 0.5773 | Val Loss: 0.6820, Val Acc: 77.24% | LR: 0.046077
# Epoch 96/200: Train Loss: 0.5770 | Val Loss: 0.6828, Val Acc: 77.38% | LR: 0.046860
# Epoch 97/200: Train Loss: 0.5788 | Val Loss: 0.7360, Val Acc: 75.36% | LR: 0.047645
# Epoch 98/200: Train Loss: 0.5840 | Val Loss: 0.7267, Val Acc: 75.10% | LR: 0.048429
# Epoch 99/200: Train Loss: 0.5757 | Val Loss: 0.6700, Val Acc: 77.64% | LR: 0.049215
# Epoch 100/200: Train Loss: 0.5735 | Val Loss: 0.8204, Val Acc: 73.44% | LR: 0.050000
# Epoch 101/200: Train Loss: 0.5794 | Val Loss: 0.6960, Val Acc: 76.82% | LR: 0.050785
# Epoch 102/200: Train Loss: 0.5710 | Val Loss: 0.7621, Val Acc: 74.64% | LR: 0.051571
# Epoch 103/200: Train Loss: 0.5731 | Val Loss: 0.6919, Val Acc: 76.60% | LR: 0.052355
# Epoch 104/200: Train Loss: 0.5753 | Val Loss: 0.7242, Val Acc: 76.04% | LR: 0.053140
# Epoch 105/200: Train Loss: 0.5649 | Val Loss: 0.6399, Val Acc: 78.86% | LR: 0.053923
# Epoch 106/200: Train Loss: 0.5669 | Val Loss: 0.7091, Val Acc: 76.48% | LR: 0.054705
# Epoch 107/200: Train Loss: 0.5624 | Val Loss: 0.6720, Val Acc: 77.04% | LR: 0.055487
# Epoch 108/200: Train Loss: 0.5667 | Val Loss: 0.7560, Val Acc: 74.98% | LR: 0.056267
# Epoch 109/200: Train Loss: 0.5610 | Val Loss: 0.6844, Val Acc: 77.04% | LR: 0.057045
# Epoch 110/200: Train Loss: 0.5642 | Val Loss: 0.7268, Val Acc: 75.20% | LR: 0.057822
# Epoch 111/200: Train Loss: 0.5659 | Val Loss: 0.7581, Val Acc: 75.48% | LR: 0.058596
# Epoch 112/200: Train Loss: 0.5622 | Val Loss: 0.6896, Val Acc: 77.42% | LR: 0.059369
# Epoch 113/200: Train Loss: 0.5627 | Val Loss: 0.6906, Val Acc: 76.50% | LR: 0.060139
# Epoch 114/200: Train Loss: 0.5613 | Val Loss: 0.7279, Val Acc: 75.60% | LR: 0.060907
# Epoch 115/200: Train Loss: 0.5632 | Val Loss: 0.6472, Val Acc: 78.14% | LR: 0.061672
# Epoch 116/200: Train Loss: 0.5587 | Val Loss: 0.7045, Val Acc: 76.64% | LR: 0.062434
# Epoch 117/200: Train Loss: 0.5573 | Val Loss: 0.6769, Val Acc: 77.52% | LR: 0.063194
# Epoch 118/200: Train Loss: 0.5640 | Val Loss: 0.6869, Val Acc: 77.30% | LR: 0.063950
# Epoch 119/200: Train Loss: 0.5621 | Val Loss: 0.6330, Val Acc: 78.98% | LR: 0.064702
# Epoch 120/200: Train Loss: 0.5585 | Val Loss: 0.6847, Val Acc: 76.90% | LR: 0.065451
# Epoch 121/200: Train Loss: 0.5551 | Val Loss: 0.6965, Val Acc: 76.82% | LR: 0.066196
# Epoch 122/200: Train Loss: 0.5551 | Val Loss: 0.7787, Val Acc: 74.16% | LR: 0.066937
# Epoch 123/200: Train Loss: 0.5546 | Val Loss: 0.6476, Val Acc: 77.68% | LR: 0.067674
# Epoch 124/200: Train Loss: 0.5519 | Val Loss: 0.6971, Val Acc: 77.56% | LR: 0.068406
# Epoch 125/200: Train Loss: 0.5547 | Val Loss: 0.7101, Val Acc: 76.66% | LR: 0.069134
# Epoch 126/200: Train Loss: 0.5525 | Val Loss: 0.7627, Val Acc: 75.46% | LR: 0.069857
# Epoch 127/200: Train Loss: 0.5512 | Val Loss: 0.6545, Val Acc: 78.32% | LR: 0.070576
# Epoch 128/200: Train Loss: 0.5432 | Val Loss: 0.6507, Val Acc: 78.16% | LR: 0.071289
# Epoch 129/200: Train Loss: 0.5511 | Val Loss: 0.7049, Val Acc: 76.70% | LR: 0.071997
# Epoch 130/200: Train Loss: 0.5501 | Val Loss: 0.6147, Val Acc: 79.38% | LR: 0.072700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_153/593982927.py in <cell line: 0>()
#      21     n_epochs = 5
#      22     logging_interval = len(train_loader)
# ---> 23     model,_,_,_,_ = fit(model, logging_interval=logging_interval)
#      24
#      25     # Final test evaluation
#
# /tmp/ipykernel_153/1851750557.py in fit(model, epochs, logging_interval)
#     183         epoch_loss = 0
#     184
# --> 185         for step, (data, target) in enumerate(train_loader):
#     186             data, target = data.to(DEVICE), target.to(DEVICE)
#     187
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1456
#    1457             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1458             idx, data = self._get_data()
#    1459             self._tasks_outstanding -= 1
#    1460             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1408         elif self._pin_memory:
#    1409             while self._pin_memory_thread.is_alive():
# -> 1410                 success, data = self._try_get_data()
#    1411                 if success:
#    1412                     return data
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1249         #   (bool: whether successfully get data, any: data if successful else None)
#    1250         try:
# -> 1251             data = self._data_queue.get(timeout=timeout)
#    1252             return (True, data)
#    1253         except Exception as e:
#
# /usr/lib/python3.11/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     329             else:
#     330                 if timeout > 0:
# --> 331                     gotit = waiter.acquire(True, timeout)
#     332                 else:
#     333                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
plt.scatter(range(5), test_accs, c="b")
plt.xlabel("Seed")
plt.ylabel("Test acc")
plt.ylim(min(test_accs) - 5, max(test_accs) + 5)
plt.grid(True, ls=':')
plt.xticks(range(5))
plt.show()

# %% [markdown]
# ## Questions
#
# During the presentation, we may ask questions to ensure you have understood the core concepts of the course. Examples include:
# 1. Where are the parameters that a CNN learns during training?
# 2. Why do we use convolutional layers instead of fully connected layers for image data?
# 3. What is the role of pooling layers? What would happen if we removed them?
# 4. What is Dropout? Batch Normalizaton? Do you have other regularization tecniques in mind?
